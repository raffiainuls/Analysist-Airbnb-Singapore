# %% [markdown]
# # Preparation Data

# %%
# !pip install pandasql
# !pip install haversine
from haversine import haversine, Unit
import matplotlib.pyplot as plt
from google.colab import drive
import pandas as pd
import pandasql as ps
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import numpy as np
from scipy.stats import gaussian_kde
from datetime import datetime
import math
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pandasql
#   Downloading pandasql-0.7.3.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from pandasql) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from pandasql) (1.4.4)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.9/dist-packages (from pandasql) (1.4.47)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->pandasql) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->pandasql) (2.8.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from sqlalchemy->pandasql) (2.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->pandasql) (1.16.0)
# Building wheels for collected packages: pandasql
#   Building wheel for pandasql (setup.py) ... done
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26784 sha256=061ec5330b87d578ea1271460da7723b82c0f58fe2a318a3f4ac780a0e512984
#   Stored in directory: /root/.cache/pip/wheels/63/e8/ec/75b1df467ecf57b6ececb32cb16f4e86697cbfe55cb0c51f07
# Successfully built pandasql
# Installing collected packages: pandasql
# Successfully installed pandasql-0.7.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting haversine
#   Downloading haversine-2.8.0-py2.py3-none-any.whl (7.7 kB)
# Installing collected packages: haversine
# Successfully installed haversine-2.8.0

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Ubah lokasi direktori kerja
# Sesuaikan dengan path anda
# %cd /content/drive/MyDrive/Project DQLab Airbnb
# Out:
# /content/drive/MyDrive/Project DQLab Airbnb

# %%
ls
# Out:
# 'Copy of DQLab_listings(22Sep2022) (1).csv'
# 'Copy of DQLab_listings(22Sep2022).xlsx'
# 'Copy of DQLab_nieghbourhood(22Sep2022).csv'
# 'Copy of DQLab_nieghbourhood(22Sep2022).xlsx'
# 'Copy of DQLab_reviews(22Sep2022).csv'
# 'Copy of DQLab_reviews(22Sep2022).xlsx'
# 'Copy of Guideline Portfolio project _ Python andSQL (1).pdf'
# 'DQLab_listings(22Sep2022) (1).gsheet'

# %%
data_listings = pd.read_csv("Copy of DQLab_listings(22Sep2022) (1).csv")
data_reviews = pd.read_csv("Copy of DQLab_reviews(22Sep2022).csv")
data_nieghbourhood = pd.read_csv("Copy of DQLab_nieghbourhood(22Sep2022).csv")

# %%
data_listings
# Out:
#       Unnamed: 0                  id  \
# 0              0               50646
# 1              1               71609
# 2              2               71896
# 3              3               71903
# 4              4              275344
# ...          ...                 ...
# 4156        4156  720000271010003429
# 4157        4157  720000552643956732
# 4158        4158  720695231887902167
# 4159        4159  720724511357857504
# 4160        4160  720811961088959403
#
#                                                    name    host_id  \
# 0                       Pleasant Room along Bukit Timah     227796
# 1                   Ensuite Room (Room 1 & 2) near EXPO     367042
# 2                       B&B  Room 1 near Airport & EXPO     367042
# 3                            Room 2-near Airport & EXPO     367042
# 4                     15 mins to Outram MRT Single Room    1439258
# ...                                                 ...        ...
# 4156   Marine Parade 2br w/ gym, bbq & pool, nr airport  466330896
# 4157    Orchard 2br w/ gym, bbq & pool, nr Somerset MRT  466330896
# 4158                                 Zi Xuan Apartments  480404953
# 4159     #7 Studio with toilet & kitchen @Sks Pavillion  158018542
# 4160  新加坡滨海湾金沙酒店含无边泳池空中花园健身房付费下午茶鸡尾酒早餐海景城景需要升级城景俱乐部房...  467355165
#
#        host_name  neighbourhood  latitude   longitude        room_type  price  \
# 0        Sujatha    Bukit Timah  1.334320  103.785210     Private room     80
# 1        Belinda       Tampines  1.345370  103.958870     Private room    145
# 2        Belinda       Tampines  1.347540  103.959580     Private room     85
# 3        Belinda       Tampines  1.345310  103.961000     Private room     85
# 4            Kay    Bukit Merah  1.288360  103.811440     Private room     49
# ...          ...            ...       ...         ...              ...    ...
# 4156  Blueground  Marine Parade  1.299569  103.898567  Entire home/apt    263
# 4157  Blueground         Newton  1.301816  103.839077  Entire home/apt    354
# 4158   Natividad         Newton  1.307921  103.831502  Entire home/apt    398
# 4159      Betris      Woodlands  1.470580  103.762420     Private room     27
# 4160        Deng  Downtown Core  1.282065  103.858714     Private room    813
#
#       minimum_nights  availability_365
# 0                 92               365
# 1                 92               340
# 2                 92               265
# 3                 92               365
# 4                 60               296
# ...              ...               ...
# 4156              92               365
# 4157              92               365
# 4158               4               358
# 4159               1                87
# 4160               1               359
#
# [4161 rows x 12 columns]

# %%
data_nieghbourhood
# Out:
#     Unnamed: 0 neighbourhood_group            neighbourhood
# 0            0      Central Region                   Bishan
# 1            1      Central Region              Bukit Merah
# 2            2      Central Region              Bukit Timah
# 3            3      Central Region            Downtown Core
# 4            4      Central Region                  Geylang
# 5            5      Central Region                  Kallang
# 6            6      Central Region              Marina East
# 7            7      Central Region             Marina South
# 8            8      Central Region            Marine Parade
# 9            9      Central Region                   Museum
# 10          10      Central Region                   Newton
# 11          11      Central Region                   Novena
# 12          12      Central Region                  Orchard
# 13          13      Central Region                   Outram
# 14          14      Central Region               Queenstown
# 15          15      Central Region             River Valley
# 16          16      Central Region                   Rochor
# 17          17      Central Region          Singapore River
# 18          18      Central Region         Southern Islands
# 19          19      Central Region             Straits View
# 20          20      Central Region                  Tanglin
# 21          21      Central Region                Toa Payoh
# 22          22         East Region                    Bedok
# 23          23         East Region                   Changi
# 24          24         East Region               Changi Bay
# 25          25         East Region                Pasir Ris
# 26          26         East Region               Paya Lebar
# 27          27         East Region                 Tampines
# 28          28   North-East Region               Ang Mo Kio
# 29          29   North-East Region                  Hougang
# 30          30   North-East Region    North-Eastern Islands
# 31          31   North-East Region                  Punggol
# 32          32   North-East Region                  Seletar
# 33          33   North-East Region                 Sengkang
# 34          34   North-East Region                Serangoon
# 35          35        North Region  Central Water Catchment
# 36          36        North Region             Lim Chu Kang
# 37          37        North Region                   Mandai
# 38          38        North Region                Sembawang
# 39          39        North Region                  Simpang
# 40          40        North Region             Sungei Kadut
# 41          41        North Region                Woodlands
# 42          42        North Region                   Yishun
# 43          43         West Region                 Boon Lay
# 44          44         West Region              Bukit Batok
# 45          45         West Region            Bukit Panjang
# 46          46         West Region            Choa Chu Kang
# 47          47         West Region                 Clementi
# 48          48         West Region              Jurong East
# 49          49         West Region              Jurong West
# 50          50         West Region                  Pioneer
# 51          51         West Region                   Tengah
# 52          52         West Region                     Tuas
# 53          53         West Region          Western Islands
# 54          54         West Region  Western Water Catchment

# %%
data_reviews
# Out:
#        Unnamed: 0          listing_id        date
# 0              28               71609  2018-07-14
# 1              29               71609  2019-01-06
# 2              30               71609  2019-07-27
# 3              31               71609  2019-08-11
# 4              32               71609  2019-09-07
# ...           ...                 ...         ...
# 49690       58245  712907319520281078  2022-09-14
# 49691       58246  712907319520281078  2022-09-15
# 49692       58247  712907319520281078  2022-09-16
# 49693       58248  713608959415048233  2022-09-17
# 49694       58249  716323913372695477  2022-09-18
#
# [49695 rows x 3 columns]

# %% [markdown]
# # Exploratory  Data

# %% [markdown]
# Join Data Menggunakan SQL

# %%
dataset= ps.sqldf(""" select dl.id, dl.name, dl.host_id, dl.host_name, dl.neighbourhood, dl.latitude, dl.longitude,dl.room_type, dl.price, dl.minimum_nights, dl.availability_365, dn.neighbourhood_group,  dr.date as review_date
                        from data_listings as dl
                        left join data_nieghbourhood as dn on dl.neighbourhood = dn.neighbourhood
                        left join data_reviews as dr on dl.id = dr.listing_id 
                        order by dl.host_id
                        
                        
                        """)
dataset = dataset.dropna()

# %% [markdown]
# Menambahkan Column last_review dan total review

# %%
data= ps.sqldf(""" select dl.id, dl.name, dl.host_id, dl.host_name, dl.neighbourhood, dl.latitude, dl.longitude,dl.room_type, dl.price, dl.minimum_nights, dl.availability_365, dn.neighbourhood_group,  MAX(dr.date) as last_review, count(dr.listing_id) as total_review
                        from data_listings as dl
                        left join data_nieghbourhood as dn on dl.neighbourhood = dn.neighbourhood
                        left join data_reviews as dr on dl.id = dr.listing_id 
                        group by dl.id
                        order by dl.price desc
                        
                        """)


data = data.dropna()
data
# Out:
#             id                                               name    host_id  \
# 0     28601709      富力公主湾商场公寓 R&F Mall, link bridge to JB Customs   65839450
# 4     14289091                           One bed room condominium   87219452
# 7     36461692      [TOP PICK] Country Garden, JB (WIFI GYM POOL)  150501550
# 14    35105091             Cosy 2BR Teega Residence near Legoland  163025370
# 15    41606210  【Above R&F】Golden Egg-Walk to CIQ JBCC CS（6-8PAX）  328044392
# ...        ...                                                ...        ...
# 4148  37302795              DRAGON INN PREMIUM HOTEL (JB) SDN BHD  280825642
# 4153  38224254          [Bungalow Homestay] Johor Bahru Bedroom 4  290427273
# 4154  29837000             R&F Princess Cove common room for rent   31557595
# 4155  15544996       Bedroom in JB with quick access to Singapore  100026900
# 4156  53190609                                  Yaya's Staycation  266051529
#
#          host_name            neighbourhood  latitude  longitude  \
# 0              Lin                Woodlands   1.46030  103.76888
# 4          Michael                Pasir Ris   1.37620  103.96172
# 7           Asyraf             Lim Chu Kang   1.46567  103.72744
# 14           Sharm  Western Water Catchment   1.41382  103.65441
# 15          Golden                Woodlands   1.46035  103.77139
# ...            ...                      ...       ...        ...
# 4148         Ramir                Woodlands   1.45951  103.76555
# 4153      Akmalina             Sungei Kadut   1.46426  103.74413
# 4154           Jay                Woodlands   1.45856  103.76684
# 4155  Dharmalingam                Woodlands   1.47115  103.76966
# 4156       Shareff                Woodlands   1.47525  103.78119
#
#             room_type  price  minimum_nights  availability_365  \
# 0     Entire home/apt  12494               2               181
# 4     Entire home/apt   7286              92                 0
# 7     Entire home/apt   4660              30               180
# 14    Entire home/apt   3107               5                80
# 15    Entire home/apt   3106              60               268
# ...               ...    ...             ...               ...
# 4148       Hotel room     19               1               144
# 4153     Private room     16               1                90
# 4154     Private room     16              30               332
# 4155     Private room     16               1                91
# 4156     Private room     15               1               342
#
#      neighbourhood_group last_review  total_review
# 0           North Region  2019-10-28             1
# 4            East Region  2018-09-29             1
# 7           North Region  2020-03-15            31
# 14           West Region  2022-05-03             4
# 15          North Region  2020-03-29             9
# ...                  ...         ...           ...
# 4148        North Region  2019-12-01             1
# 4153        North Region  2019-09-17             1
# 4154        North Region  2022-08-17             1
# 4155        North Region  2020-02-04             1
# 4156        North Region  2022-08-08            24
#
# [2486 rows x 14 columns]

# %% [markdown]
# ## Statistik Deskriptif

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2486 entries, 0 to 4156
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   2486 non-null   int64
#  1   name                 2486 non-null   object
#  2   host_id              2486 non-null   int64
#  3   host_name            2486 non-null   object
#  4   neighbourhood        2486 non-null   object
#  5   latitude             2486 non-null   float64
#  6   longitude            2486 non-null   float64
#  7   room_type            2486 non-null   object
#  8   price                2486 non-null   int64
#  9   minimum_nights       2486 non-null   int64
#  10  availability_365     2486 non-null   int64
#  11  neighbourhood_group  2486 non-null   object
#  12  last_review          2486 non-null   object
#  13  total_review         2486 non-null   int64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 291.3+ KB

# %%
data.describe()
# Out:
#                  id       host_id     latitude    longitude         price  \
# count  2.486000e+03  2.486000e+03  2486.000000  2486.000000   2486.000000
# mean   1.154330e+17  1.571637e+08     1.358427   103.805941    163.972245
# std    2.458893e+17  1.370890e+08     0.072762     0.070410    355.829136
# min    7.160900e+04  2.366600e+04     1.256442   103.638880     15.000000
# 25%    2.412669e+07  4.187059e+07     1.298272   103.767753     54.000000
# 50%    3.723853e+07  1.243226e+08     1.317130   103.835140     88.000000
# 75%    5.177657e+07  2.582789e+08     1.457530   103.854507    183.000000
# max    7.163239e+17  4.787832e+08     1.488000   103.977662  12494.000000
#
#        minimum_nights  availability_365  total_review
# count     2486.000000       2486.000000   2486.000000
# mean        45.527755        239.886967     19.989944
# std         65.186350        129.230761     38.227092
# min          1.000000          0.000000      1.000000
# 25%          1.000000        115.250000      2.000000
# 50%          6.000000        295.000000      5.000000
# 75%         92.000000        357.000000     19.000000
# max       1000.000000        365.000000    413.000000

# %%
data.hist(bins=50, figsize=(20,15))
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.kdeplot(data.price, shade=True)
sns.rugplot(data.price, color='r')
plt.title('Distribusi Harga Listing Airbnb di Singapura', fontsize=16)
plt.xlabel('Harga per malam (SGD)', fontsize=14)
plt.ylabel('Kepadatan', fontsize=14)
plt.xlim(0, 800)
plt.show()
# Out:
# <ipython-input-14-45e7acf49aad>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data.price, shade=True)

# %% [markdown]
# Outlier pada data

# %%
sns.set(style ="whitegrid")
plt.figure(figsize = (10,6))
sns.boxplot(x=data['price'])
plt.title("Boxplot of Airbnb Listing Prices in Singapore")
plt.xlabel("Price")
plt.show()

# %% [markdown]
# Menghapus Outlier pada data

# %%
Q1 = data['price'].quantile(0.25)
Q3 = data['price'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (0.4 * IQR)

df = data[(data['price'] > lower_bound) & (data['price'] < upper_bound)]
df
# Out:
#                       id                                               name  \
# 1050  635937428811021850         New Cozy Studio Apt@ Somerset/Orchard Area
# 1052  549186561382713865  NEW Deluxe Comfy Studio Apt @Orchard/Somerset ...
# 1061            54205551      Serviced apartment- Unique Penthhouse in city
# 1062            54204802        Novena Serviced Apartment - Luxe Penthhouse
# 1067            23045739  Executive SG Clean Apartment in Singapore Central
# ...                  ...                                                ...
# 4148            37302795              DRAGON INN PREMIUM HOTEL (JB) SDN BHD
# 4153            38224254          [Bungalow Homestay] Johor Bahru Bedroom 4
# 4154            29837000             R&F Princess Cove common room for rent
# 4155            15544996       Bedroom in JB with quick access to Singapore
# 4156            53190609                                  Yaya's Staycation
#
#         host_id     host_name neighbourhood  latitude   longitude  \
# 1050   10248444     Binh Chan  River Valley  1.294390  103.838610
# 1052   10248444     Binh Chan  River Valley  1.294800  103.838410
# 1061   24496358     Katherine        Novena  1.318524  103.847511
# 1062   68059127           Wei        Novena  1.318524  103.847511
# 1067  148161755           Jan        Rochor  1.298060  103.852570
# ...         ...           ...           ...       ...         ...
# 4148  280825642         Ramir     Woodlands  1.459510  103.765550
# 4153  290427273      Akmalina  Sungei Kadut  1.464260  103.744130
# 4154   31557595           Jay     Woodlands  1.458560  103.766840
# 4155  100026900  Dharmalingam     Woodlands  1.471150  103.769660
# 4156  266051529       Shareff     Woodlands  1.475250  103.781190
#
#             room_type  price  minimum_nights  availability_365  \
# 1050  Entire home/apt    233               2               325
# 1052  Entire home/apt    233               2               345
# 1061  Entire home/apt    230               6               277
# 1062  Entire home/apt    230               6               277
# 1067  Entire home/apt    230               6                 0
# ...               ...    ...             ...               ...
# 4148       Hotel room     19               1               144
# 4153     Private room     16               1                90
# 4154     Private room     16              30               332
# 4155     Private room     16               1                91
# 4156     Private room     15               1               342
#
#      neighbourhood_group last_review  total_review
# 1050      Central Region  2022-08-18             3
# 1052      Central Region  2022-09-07             8
# 1061      Central Region  2022-05-23             1
# 1062      Central Region  2022-09-17             2
# 1067      Central Region  2022-09-17             8
# ...                  ...         ...           ...
# 4148        North Region  2019-12-01             1
# 4153        North Region  2019-09-17             1
# 4154        North Region  2022-08-17             1
# 4155        North Region  2020-02-04             1
# 4156        North Region  2022-08-08            24
#
# [2050 rows x 14 columns]

# %%
df.sort_values(by= "price")
# Out:
#                       id                                               name  \
# 4156            53190609                                  Yaya's Staycation
# 4153            38224254          [Bungalow Homestay] Johor Bahru Bedroom 4
# 4155            15544996       Bedroom in JB with quick access to Singapore
# 4154            29837000             R&F Princess Cove common room for rent
# 4148            37302795              DRAGON INN PREMIUM HOTEL (JB) SDN BHD
# ...                  ...                                                ...
# 1067            23045739  Executive SG Clean Apartment in Singapore Central
# 1062            54204802        Novena Serviced Apartment - Luxe Penthhouse
# 1061            54205551      Serviced apartment- Unique Penthhouse in city
# 1052  549186561382713865  NEW Deluxe Comfy Studio Apt @Orchard/Somerset ...
# 1050  635937428811021850         New Cozy Studio Apt@ Somerset/Orchard Area
#
#         host_id     host_name neighbourhood  latitude   longitude  \
# 4156  266051529       Shareff     Woodlands  1.475250  103.781190
# 4153  290427273      Akmalina  Sungei Kadut  1.464260  103.744130
# 4155  100026900  Dharmalingam     Woodlands  1.471150  103.769660
# 4154   31557595           Jay     Woodlands  1.458560  103.766840
# 4148  280825642         Ramir     Woodlands  1.459510  103.765550
# ...         ...           ...           ...       ...         ...
# 1067  148161755           Jan        Rochor  1.298060  103.852570
# 1062   68059127           Wei        Novena  1.318524  103.847511
# 1061   24496358     Katherine        Novena  1.318524  103.847511
# 1052   10248444     Binh Chan  River Valley  1.294800  103.838410
# 1050   10248444     Binh Chan  River Valley  1.294390  103.838610
#
#             room_type  price  minimum_nights  availability_365  \
# 4156     Private room     15               1               342
# 4153     Private room     16               1                90
# 4155     Private room     16               1                91
# 4154     Private room     16              30               332
# 4148       Hotel room     19               1               144
# ...               ...    ...             ...               ...
# 1067  Entire home/apt    230               6                 0
# 1062  Entire home/apt    230               6               277
# 1061  Entire home/apt    230               6               277
# 1052  Entire home/apt    233               2               345
# 1050  Entire home/apt    233               2               325
#
#      neighbourhood_group last_review  total_review
# 4156        North Region  2022-08-08            24
# 4153        North Region  2019-09-17             1
# 4155        North Region  2020-02-04             1
# 4154        North Region  2022-08-17             1
# 4148        North Region  2019-12-01             1
# ...                  ...         ...           ...
# 1067      Central Region  2022-09-17             8
# 1062      Central Region  2022-09-17             2
# 1061      Central Region  2022-05-23             1
# 1052      Central Region  2022-09-07             8
# 1050      Central Region  2022-08-18             3
#
# [2050 rows x 14 columns]

# %%
df.describe()
# Out:
#                  id       host_id     latitude    longitude        price  \
# count  2.050000e+03  2.050000e+03  2050.000000  2050.000000  2050.000000
# mean   1.065984e+17  1.461654e+08     1.368885   103.800290    91.424390
# std    2.380990e+17  1.327082e+08     0.073198     0.073427    53.387872
# min    7.160900e+04  2.366600e+04     1.271260   103.638880    15.000000
# 25%    2.326771e+07  3.275302e+07     1.305262   103.763465    49.000000
# 50%    3.591606e+07  1.011458e+08     1.333775   103.826615    72.000000
# 75%    4.938843e+07  2.467259e+08     1.458708   103.854605   124.000000
# max    7.163239e+17  4.787832e+08     1.488000   103.967060   233.000000
#
#        minimum_nights  availability_365  total_review
# count     2050.000000       2050.000000   2050.000000
# mean        47.683415        236.270732     21.752683
# std         68.582388        129.110568     40.069581
# min          1.000000          0.000000      1.000000
# 25%          1.000000        111.000000      2.000000
# 50%          6.000000        288.000000      6.000000
# 75%         92.000000        356.000000     22.000000
# max       1000.000000        365.000000    413.000000

# %%
sns.set(style ="whitegrid")
plt.figure(figsize = (10,6))
sns.boxplot(x=df['price'])
plt.title("Boxplot of Airbnb Listing Prices in Singapore")
plt.xlabel("Price")
plt.show()

# %% [markdown]
# ## Top Host Name

# %%
data_top_host_name_10 = ps.sqldf(""" select host_id, host_name, count(id) as total_listing, sum(total_review) as total_review
                                  from data
                                  group by host_id
                                  order by total_review desc
                                  limit 10
                            """)

data_top_host_name = ps.sqldf(""" select host_id, host_name, count(id) as total_listing, sum(total_review) as total_review
                                  from data
                                  group by host_id
                                  order by total_review desc
                                  
                            """)
data_top_host_name
# Out:
#        host_id           host_name  total_listing  total_review
# 0    136700088  Bryce [RentRadise]             34          5073
# 1    260813040              Havona             33          2800
# 2     41870590      UHA Management             59          1388
# 3     23336011            Heritage             37          1335
# 4     31490114      Robin & Louise             22           837
# ..         ...                 ...            ...           ...
# 699   12422759           Christine              1             1
# 700    8686808                  Jx              1             1
# 701    6578888                 Vic              1             1
# 702    5556667               David              1             1
# 703    4360831               Laura              1             1
#
# [704 rows x 4 columns]

# %% [markdown]
# Visualisasi Top Host Name

# %%
colors = ["#FFACAC","#FFBFA9","#FFBFA9","#FFBFA9","#FFBFA9","#FFBFA9","#FFBFA9","#FFBFA9","#FFBFA9","#FFBFA9"]


plot_top_10_review = px.bar(data_top_host_name_10, x="host_name", y="total_review", color="host_name", color_discrete_sequence=colors, template="ggplot2")



# modify Title
plot_top_10_review.update_layout(title = "<b>Top 10 Host Name According Total Review<b>", title_font= dict(size = 20, color= "black", family = "arial"),title_x=0.5)

#update label x dan y
plot_top_10_review.update_xaxes(title= "<b> Host name <b>", title_font= dict(size = 15, color="black", family = "arial"))
plot_top_10_review.update_yaxes(title = "<b> Total Reviews", title_font= dict(size = 15, color = "black", family = "arial"))

# update xtick dan ytick
plot_top_10_review.update_xaxes(tickfont=dict(size=13, family="arial", color = "black"),tickangle=10)



plot_top_10_review.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="9eadeddf-7694-4e2d-a50f-f12ab335a062" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9eadeddf-7694-4e2d-a50f-f12ab335a062")) {                    Plotly.newPlot(                        "9eadeddf-7694-4e2d-a50f-f12ab335a062",                        [{"alignmentgroup":"True","hovertemplate":"host_name=%{x}<br>total_review=%{y}<extra></extra>","legendgroup":"Bryce [RentRadise]","marker":{"color":"#FFACAC","pattern":{"shape":""}},"name":"Bryce [RentRadise]","offsetgroup":"Bryce [RentRadise]","orientation":"v","showlegend":true,"textposition":"auto","x":["Bryce [RentRadise]"],"xaxis":"x","y":[5073],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"host_name=%{x}<br>total_review=%{y}<extra></extra>","legendgroup":"Havona","marker":{"color":"#FFBFA9","pattern":{"shape":""}},"name":"Havona","offsetgroup":"Havona","orientation":"v","showlegend":true,"textposition":"auto","x":["Havona"],"xaxis":"x","y":[2800],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"host_name=%{x}<br>total_review=%{y}<extra></extra>","legendgroup":"UHA Management","marker":{"color":"#FFBFA9","pattern":{"shape":""}},"name":"UHA Management","offsetgroup":"UHA Management","orientation":"v","showlegend":true,"textposition":"auto","x":["UHA Management"],"xaxis":"x","y":[1388],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"host_name=%{x}<br>total_review=%{y}<extra></extra>","legendgroup":"Heritage","marker":{"color":"#FFBFA9","pattern":{"shape":""}},"name":"Heritage","offsetgroup":"Heritage","orientation":"v","showlegend":true,"textposition":"auto","x":["Heritage"],"xaxis":"x","y":[1335],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"host_name=%{x}<br>total_review=%{y}<extra></extra>","legendgroup":"Robin & Louise","marker":{"color":"#FFBFA9","pattern":{"shape":""}},"name":"Robin & Louise","offsetgroup":"Robin & Louise","orientation":"v","showlegend":true,"textposition":"auto","x":["Robin & Louise"],"xaxis":"x","y":[837],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"host_name=%{x}<br>total_review=%{y}<extra></extra>","legendgroup":"Advante Homes","marker":{"color":"#FFBFA9","pattern":{"shape":""}},"name":"Advante Homes","offsetgroup":"Advante Homes","orientation":"v","showlegend":true,"textposition":"auto","x":["Advante Homes"],"xaxis":"x","y":[619],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"host_name=%{x}<br>total_review=%{y}<extra></extra>","legendgroup":"Keith Kok","marker":{"color":"#FFBFA9","pattern":{"shape":""}},"name":"Keith Kok","offsetgroup":"Keith Kok","orientation":"v","showlegend":true,"textposition":"auto","x":["Keith Kok"],"xaxis":"x","y":[593],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"host_name=%{x}<br>total_review=%{y}<extra></extra>","legendgroup":"Welcome Home Decor & Management","marker":{"color":"#FFBFA9","pattern":{"shape":""}},"name":"Welcome Home Decor & Management","offsetgroup":"Welcome Home Decor & Management","orientation":"v","showlegend":true,"textposition":"auto","x":["Welcome Home Decor & Management"],"xaxis":"x","y":[570],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"host_name=%{x}<br>total_review=%{y}<extra></extra>","legendgroup":"Eddie","marker":{"color":"#FFBFA9","pattern":{"shape":""}},"name":"Eddie","offsetgroup":"Eddie","orientation":"v","showlegend":true,"textposition":"auto","x":["Eddie"],"xaxis":"x","y":[547],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"host_name=%{x}<br>total_review=%{y}<extra></extra>","legendgroup":"Kym","marker":{"color":"#FFBFA9","pattern":{"shape":""}},"name":"Kym","offsetgroup":"Kym","orientation":"v","showlegend":t ...

# %%
m, c = np.polyfit(data_top_host_name['total_listing'], data_top_host_name['total_review'], 1)
print(m, c)
print(data_top_host_name['total_review'].corr(data_top_host_name['total_listing']))

X1 = 0
X2 = 217
y1 = m * X1 + c
y2 = m * X2 + c

# Melihat scatter plot
plt.scatter(data_top_host_name['total_listing'], data_top_host_name['total_review'])

## PENAMBAHAN GARIS REGRESI ##
plt.plot([X1, X2], [y1, y2], 'k--')

plt.show()
# Out:
# 15.182362056398384 16.976772624707102
# 0.42825883868106757

# %% [markdown]
# ## Mencari Top Minimum Profit

# %%
data_profit_minimum_top_host_name = ps.sqldf(""" select id, name, host_id, host_name, count(id) as Total_Listing, price, minimum_nights, sum(total_review) total_reviews, (price * minimum_nights * total_review) as minimum_profit
                                                 from data
                                                 WHERE host_name IN ('Bryce [RentRadise]', 'Havona', 'UHA Management', 'Heritage', 'Robin & Louise', 'Advante Homes', 'Keith Kok', 'Welcome Home Decor & Management', 'Eddie', 'Kym')
                                                 group by id
                                                 order by minimum_profit desc                                           
                                            
                                            """)
data_profit_minimum_top_host_name
# Out:
#                      id                                               name  \
# 0               5827713                              The Private Sanctuary
# 1               5919270                                 The Antiquity Room
# 2               5827998                                      The Lily Room
# 3               5798211                                   The Studio Suite
# 4               8180346                                       The Zen Room
# ..                  ...                                                ...
# 232  612517667124973386       🦋【Anivia Suite】🀄〖Sky Habitat🍟🍔Johor Bahru〗❤️
# 233  612490099959375922         🦋【Kalista Suite】💫〖R&F Mall🍴🛒Johor Bahru〗❤️
# 234            53597569     🌻【Gemini Suite】🚌〖Komtar JBCC 🛒🛍️Johor Bahru〗❤️
# 235  686416083748002431  Aura⋅Country Garden Danga Bay⋅2BR 4Pax⋅Johor B...
# 236  625865383981856688  #Lovely Victorian Home with Great Marina views...
#
#       host_id       host_name  Total_Listing  price  minimum_nights  \
# 0    30080617           Eddie              1     70              92
# 1    30080617           Eddie              1     80              92
# 2    30080617           Eddie              1     60              92
# 3    30080617           Eddie              1     70              92
# 4    30080617           Eddie              1     45              92
# ..        ...             ...            ...    ...             ...
# 232  41870590  UHA Management              1     94               1
# 233  41870590  UHA Management              1     93               1
# 234  41870590  UHA Management              1     44               1
# 235  41870590  UHA Management              1     76               1
# 236  31490114  Robin & Louise              1     59               1
#
#      total_reviews  minimum_profit
# 0              126          811440
# 1              103          758080
# 2              124          684480
# 3               90          579600
# 4              104          430560
# ..             ...             ...
# 232              1              94
# 233              1              93
# 234              2              88
# 235              1              76
# 236              1              59
#
# [237 rows x 9 columns]

# %%
data_profit_minimum_top_host_name_fix= ps.sqldf(""" select host_name, sum(Total_Listing) as total_listing, avg(price), avg(minimum_nights), sum(total_reviews) as total_reviews, sum(minimum_profit) as total_profit
                                                from data_profit_minimum_top_host_name
                                                group by host_name
                                                order by total_profit desc
                                                limit 3


                                          """)
data_profit_minimum_top_host_name_fix
# Out:
#             host_name  total_listing  avg(price)  avg(minimum_nights)  \
# 0               Eddie              5   65.000000            92.000000
# 1  Bryce [RentRadise]             34   47.529412             1.852941
# 2            Heritage             37  233.648649             1.054054
#
#    total_reviews  total_profit
# 0            547       3264160
# 1           5073        335005
# 2           1335        296548

# %% [markdown]
# Visualisasi Top 3 Minimum

# %%
top_minimum_profit = px.bar(data_profit_minimum_top_host_name_fix,x = "host_name", y="total_profit",template= "ggplot2")

# modify title
top_minimum_profit.update_layout(title ="<b> Top 3 Minimum Profit", title_font = dict(size = 20, color = "black", family = "arial"), title_x = 0.5)

# Update label x dan y

top_minimum_profit.update_xaxes(title = "Host Name", title_font = dict(size = 15, color = "black", family = "arial"))
top_minimum_profit.update_yaxes(title = "Minimum Profit (USD)", title_font= dict(size= 15, color = "black", family = "arial"))
top_minimum_profit.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c799f37c-5649-4246-89c2-8e034d54e384" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c799f37c-5649-4246-89c2-8e034d54e384")) {                    Plotly.newPlot(                        "c799f37c-5649-4246-89c2-8e034d54e384",                        [{"alignmentgroup":"True","hovertemplate":"host_name=%{x}<br>total_profit=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#F8766D","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Eddie","Bryce [RentRadise]","Heritage"],"xaxis":"x","y":[3264160,335005,296548],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(51,51,51)"},"error_y":{"color":"rgb(51,51,51)"},"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"baxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scattergl"}],"scattermapbox":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scattermapbox" ...

# %% [markdown]
# ## Distribusi Harga Airbnb Singapore

# %% [markdown]
# Distribusi Keseluruhan

# %%
# calculate kernel density estimation 
kde = gaussian_kde(df["price"])
x = np.linspace(df['price'].min(), df['price'].max())
y = kde(x)

# create histogram plot
plot_dis_price = px.histogram(x=df['price'], nbins = 50, template = "ggplot2", opacity = 0.5)

# add kde plot
plot_dis_price.add_trace(go.Scatter(x=x,
                                    y=y,
                                    name="Density",
                                    yaxis= "y2",
                                    line=dict(color= "red", width= 3)
                                    ))

# set title, axis labels and layout 
plot_dis_price.update_layout(title= "<b>Distribusi Harga Airbnb Singapore<b>", 
                             title_font = dict(size = 20, color = "black", 
                             family = "arial"), 
                             title_x = 0.5,
                             bargap = 0.05, 
                             bargroupgap = 0.2, 
                             legend = dict(x=1.05, y= 1))

# update xaxes 
plot_dis_price.update_xaxes(title = "Price", title_font = dict(size = 18, color = "black", family= "arial"))

# update yaxes
plot_dis_price.update_yaxes(title = "Count", title_font = dict(size = 18, color = "black", family = "arial"))

# set second yaxis scale for the kde plot
plot_dis_price.update_layout(yaxis2 = dict(title = "Density", 
                                           title_font = dict(size = 18,family = "arial"), 
                                           overlaying ='y', 
                                           side = 'right'))
plot_dis_price.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="47fd47e2-e73c-4b0d-a932-92be5639568e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47fd47e2-e73c-4b0d-a932-92be5639568e")) {                    Plotly.newPlot(                        "47fd47e2-e73c-4b0d-a932-92be5639568e",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"x=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#F8766D","opacity":0.5,"pattern":{"shape":""}},"name":"","nbinsx":50,"offsetgroup":"","orientation":"v","showlegend":false,"x":[233,233,230,230,230,229,229,228,228,228,228,228,228,228,228,227,226,225,225,224,224,224,223,223,223,223,223,223,223,223,223,223,223,223,222,222,222,222,220,220,220,220,220,220,219,219,219,218,217,217,216,216,216,215,215,214,214,213,213,212,212,211,211,210,210,210,210,210,210,210,209,209,208,208,208,208,207,206,206,206,205,205,203,203,203,203,202,201,201,200,200,200,200,200,200,200,200,200,200,200,200,200,200,200,200,200,200,200,200,200,200,200,200,200,200,200,198,198,198,198,198,198,196,196,196,196,195,195,195,194,193,192,192,192,190,190,190,190,190,190,190,190,190,190,190,190,190,190,190,190,190,190,190,190,190,189,189,189,188,188,188,188,188,188,188,187,186,186,186,186,186,185,185,185,185,184,184,184,183,183,183,183,183,183,183,183,183,182,182,182,181,181,181,181,181,180,180,180,180,180,180,180,180,180,180,180,180,180,180,180,180,180,180,179,179,179,179,179,178,178,178,178,178,176,175,175,175,175,175,175,175,175,175,175,175,175,175,174,174,174,174,174,173,173,173,173,172,172,172,172,172,172,172,172,172,171,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,170,169,169,169,169,169,168,168,168,168,166,165,165,165,165,165,165,165,165,165,165,165,165,165,165,164,164,164,163,163,162,162,162,162,161,161,161,160,160,160,160,160,160,160,160,160,160,160,160,160,160,160,160,160,159,159,159,158,158,156,156,156,156,156,155,155,155,155,155,155,155,155,155,155,154,154,154,153,151,151,151,151,151,151,150,150,150,150,150,150,150,150,150,150,150,150,150,150,150,150,150,150,149,149,149,149,149,148,148,148,147,147,147,146,146,145,145,145,145,145,145,145,145,145,145,145,144,144,144,144,144,144,144,144,144,142,142,142,141,141,141,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,140,139,139,139,138,137,137,137,137,137,137,136,136,136,136,136,135,135,134,134,133,132,131,131,131,131,130,130,130,130,130,130,130,130,130,130,130,130,130,130,130,130,130,130,130,129,129,129,129,128,127,127,127,127,126,126,126,126,126,126,126,126,126,126,126,125,125,125,125,125,125,125,125,124,124,124,124,124,123,123,123,123,122,122,122,122,121,121,121,121,121,121,121,121,121,120,120,120,120,120,120,120,120,120,120,120,120,120,120,120,120,120,120,120,120,120,120,119,119,119,119,119,119,119,118,118,118,118,118,118,118,117,117,116,116,116,115,115,115,115,115,115,115,115,114,114,114,114,114,114,114,113,113,113,113,113,113,113,113,113,113,113,113,113,112,112,112,112,112,111,111,111,111,111,111,111,110,110,110,110,110,110,110,110,110,110,109,109,109,109,109,109,109,108,108,108,108,107,107,107,107,107,107,107,107,107,107,107,107,106,106,106,106,106,106,106,105,105,105,105,105,105,104,104,103,103,103,103,103,103,102,102,102,102,101,101,101,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,99,99,99,99,99,99,99,98,98,98,98,98,98,98,98,98,98,98,98,98,98,98,97,97,97,96,95,95,95,95,95,95,95,94,94,94,94,94,94,94,94,94,94,94,93,93,93,93,93,93,93,93,93,92,92,92,92,92,91,91,91,90,90,90,90,90,90,90,90,90,90,90,90,90,90,90,90,90,90,90,90,90,90,90,90,90,90,90,89,89,89,89,89,89,89,89,89,89,88,88,88,88,88,88,88,88,88,88,88,88,88,87,87,87,87,87,87,87,87,87,87,87,87,87,87,87, ...

# %% [markdown]
# Distribusi Pada Neighbourhood Group

# %%
plot_dis_price_ng = px.box(df, x= "neighbourhood_group", y ="price", points = "all", color = "neighbourhood_group", color_discrete_sequence=["#5D3891","#655DBB","#3E54AC","#146C94","#19A7CE"], template = "ggplot2")

#update layout 
plot_dis_price_ng.update_layout(title = "<b>Distribusi Harga Setiap Neighbourhood Group<b>", title_font = dict(size = 20, color = "black", family = "arial"))

#update xaxes dan yaxes
plot_dis_price_ng.update_xaxes(title = "Neighbourhood Group", title_font= dict(size = 18, color = "black", family = "arial"))
plot_dis_price_ng.update_yaxes(title = "Price", title_font = dict(size =18, color = "black",family = "arial"))

plot_dis_price_ng.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c66647ef-6f09-4b9d-bce7-0ab9ccc70b26" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c66647ef-6f09-4b9d-bce7-0ab9ccc70b26")) {                    Plotly.newPlot(                        "c66647ef-6f09-4b9d-bce7-0ab9ccc70b26",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"neighbourhood_group=%{x}<br>price=%{y}<extra></extra>","legendgroup":"Central Region","marker":{"color":"#5D3891"},"name":"Central Region","notched":false,"offsetgroup":"Central Region","orientation":"v","showlegend":true,"x":["Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Ce ...

# %% [markdown]
# Distribusi Harga Pada Setiap Neighbourhood Group

# %%
# selection data with any neighbourhood_group and asign to new variabel
data_central = df[df['neighbourhood_group']== 'Central Region'].sort_values('price',ascending= False)
data_west = df[df['neighbourhood_group'] == 'West Region'].sort_values('price', ascending = False)
data_north = df[df['neighbourhood_group'] == 'North Region'].sort_values('price', ascending = False)
data_east = df[df['neighbourhood_group']== 'East Region'].sort_values('price', ascending = False)
data_north_east = df[df['neighbourhood_group'] == 'North-East Region'].sort_values('price', ascending = False)

# %%
data_central
# Out:
#                       id                                               name  \
# 1050  635937428811021850         New Cozy Studio Apt@ Somerset/Orchard Area
# 1052  549186561382713865  NEW Deluxe Comfy Studio Apt @Orchard/Somerset ...
# 1061            54205551      Serviced apartment- Unique Penthhouse in city
# 1062            54204802        Novena Serviced Apartment - Luxe Penthhouse
# 1067            23045739  Executive SG Clean Apartment in Singapore Central
# ...                  ...                                                ...
# 4133            29320287          Boutique Hostel near Singapore Sports Hub
# 4134            29319686             Boutique Hostel near Kallang Wave Mall
# 4135            29319567             Bed in dormitory near National Stadium
# 4136            29319213                Bed in Boutique Hostel @ Geylang Rd
# 4137            28794509  Bed in dormitory at 3 minute walk from Kallang...
#
#         host_id  host_name neighbourhood  latitude   longitude  \
# 1050   10248444  Binh Chan  River Valley  1.294390  103.838610
# 1052   10248444  Binh Chan  River Valley  1.294800  103.838410
# 1061   24496358  Katherine        Novena  1.318524  103.847511
# 1062   68059127        Wei        Novena  1.318524  103.847511
# 1067  148161755        Jan        Rochor  1.298060  103.852570
# ...         ...        ...           ...       ...         ...
# 4133  108773366   RedDoorz       Kallang  1.311660  103.873200
# 4134  108773366   RedDoorz       Kallang  1.311280  103.873900
# 4135  108773366   RedDoorz       Kallang  1.311470  103.873870
# 4136  108773366   RedDoorz       Kallang  1.311080  103.871760
# 4137  108773366   RedDoorz       Kallang  1.311540  103.873480
#
#             room_type  price  minimum_nights  availability_365  \
# 1050  Entire home/apt    233               2               325
# 1052  Entire home/apt    233               2               345
# 1061  Entire home/apt    230               6               277
# 1062  Entire home/apt    230               6               277
# 1067  Entire home/apt    230               6                 0
# ...               ...    ...             ...               ...
# 4133       Hotel room     22              92               365
# 4134       Hotel room     22              92               365
# 4135       Hotel room     22              92               365
# 4136       Hotel room     22              92               365
# 4137       Hotel room     22              92               365
#
#      neighbourhood_group last_review  total_review
# 1050      Central Region  2022-08-18             3
# 1052      Central Region  2022-09-07             8
# 1061      Central Region  2022-05-23             1
# 1062      Central Region  2022-09-17             2
# 1067      Central Region  2022-09-17             8
# ...                  ...         ...           ...
# 4133      Central Region  2019-08-27             8
# 4134      Central Region  2020-01-12             2
# 4135      Central Region  2019-05-24             1
# 4136      Central Region  2020-02-25             6
# 4137      Central Region  2020-03-09            22
#
# [965 rows x 14 columns]

# %%
# function for plot correlation distribution price neighbourhood in any neighbourhood_group
def plot_corr_price_neighbourhood(data):
  title = data.reset_index().at[0,'neighbourhood_group']
  corr = data_central[['neighbourhood', 'price']].groupby(['neighbourhood']).mean().sort_values('price')
  plt.figure(figsize = (15,15))
  ax = sns.heatmap(corr, annot = True, fmt = '.0f')
  font = dict(family = 'arial', size = 15)
  ax.set_xticks([])
  ax.tick_params(axis = 'y', labelsize = 15)
  ax.tick_params(axis = 'x', labelsize = 15)
  plt.title(f'Harga  Neighbourhood {title}', size = 20, pad= 30)
  plt.xlabel('Price', size = 18, labelpad = 20)
  plt.ylabel(' ')
  
  plt.show()

# %%
#showing plot
plot_corr_price_neighbourhood(data_central)
plot_corr_price_neighbourhood(data_east)
plot_corr_price_neighbourhood(data_west)
plot_corr_price_neighbourhood(data_north)
plot_corr_price_neighbourhood(data_north_east)

# %%
# function mapbox distribution price


def plot_mapbox_price_neigbourhood(data):
  title = data.reset_index().at[0,'neighbourhood_group']
  fig = px.scatter_mapbox(data_central,lat = 'latitude', lon = 'longitude', hover_name= 'name',
                          hover_data= ['neighbourhood'], color = 'price', zoom = 12,
                          mapbox_style='carto-positron')
  fig.update_layout(title = f"<b>Distribution Price {title}<b>", title_font =dict( size = 20, color = 'black', family = 'arial'), title_x = 0.5 )
  fig.show()

# %%
# showing plot
plot_mapbox_price_neigbourhood(data_central)
plot_mapbox_price_neigbourhood(data_east)
plot_mapbox_price_neigbourhood(data_west)
plot_mapbox_price_neigbourhood(data_north)
plot_mapbox_price_neigbourhood(data_north_east)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="67039d8b-c902-4dd1-b8c0-9067f4a37c86" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67039d8b-c902-4dd1-b8c0-9067f4a37c86")) {                    Plotly.newPlot(                        "67039d8b-c902-4dd1-b8c0-9067f4a37c86",                        [{"customdata":[["River Valley"],["River Valley"],["Novena"],["Novena"],["Rochor"],["Singapore River"],["Kallang"],["Bukit Merah"],["Bukit Merah"],["Bukit Merah"],["Outram"],["Bukit Merah"],["Bukit Merah"],["Bukit Merah"],["Outram"],["River Valley"],["Rochor"],["Kallang"],["Tanglin"],["Downtown Core"],["Singapore River"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["River Valley"],["River Valley"],["Rochor"],["Rochor"],["Singapore River"],["Singapore River"],["River Valley"],["Geylang"],["Tanglin"],["Outram"],["River Valley"],["River Valley"],["River Valley"],["River Valley"],["Singapore River"],["Novena"],["Queenstown"],["River Valley"],["Singapore River"],["Queenstown"],["Rochor"],["Novena"],["Kallang"],["Geylang"],["Orchard"],["Queenstown"],["Bukit Merah"],["Outram"],["Downtown Core"],["Singapore River"],["Tanglin"],["Tanglin"],["Tanglin"],["River Valley"],["Kallang"],["Bukit Merah"],["Novena"],["Bishan"],["River Valley"],["Bukit Merah"],["Geylang"],["Geylang"],["Geylang"],["Bishan"],["Rochor"],["Downtown Core"],["Downtown Core"],["River Valley"],["River Valley"],["Downtown Core"],["Queenstown"],["Singapore River"],["River Valley"],["Bishan"],["Outram"],["Orchard"],["Rochor"],["Rochor"],["Rochor"],["Novena"],["Outram"],["River Valley"],["Bukit Merah"],["Bukit Merah"],["Queenstown"],["Tanglin"],["Downtown Core"],["Tanglin"],["Bukit Merah"],["Novena"],["Novena"],["Novena"],["River Valley"],["River Valley"],["Queenstown"],["River Valley"],["Geylang"],["Geylang"],["Novena"],["River Valley"],["River Valley"],["Downtown Core"],["Downtown Core"],["Downtown Core"],["Downtown Core"],["Singapore River"],["Outram"],["Novena"],["Outram"],["Downtown Core"],["Bukit Merah"],["Bukit Merah"],["Novena"],["Geylang"],["Orchard"],["Orchard"],["Kallang"],["Queenstown"],["River Valley"],["Bukit Merah"],["Novena"],["Queenstown"],["Novena"],["Novena"],["Novena"],["Tanglin"],["Novena"],["Tanglin"],["Novena"],["Novena"],["Geylang"],["Novena"],["Downtown Core"],["Bukit Merah"],["Rochor"],["Rochor"],["Kallang"],["Rochor"],["Geylang"],["Outram"],["Kallang"],["Rochor"],["Downtown Core"],["River Valley"],["Novena"],["Kallang"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Bukit Merah"],["Queenstown"],["Queenstown"],["Downtown Core"],["Outram"],["Novena"],["Bukit Merah"],["Bukit Merah"],["Bukit Merah"],["Downtown Core"],["Tanglin"],["Bukit Merah"],["Downtown Core"],["Queenstown"],["Downtown Core"],["Tanglin"],["Bukit Merah"],["Novena"],["Novena"],["Novena"],["Novena"],["Bishan"],["Downtown Core"],["Novena"],["Bishan"],["Downtown Core"],["Queenstown"],["Bukit Merah"],["Geylang"],["River Valley"],["Rochor"],["Rochor"],["Rochor"],["Rochor"],["Downtown Core"],["Downtown Core"],["Geylang"],["Rochor"],["Rochor"],["Rochor"],["Rochor"],["River Valley"],["Bukit Merah"],["Rochor"],["Rochor"],["Rochor"],["Singapore River"],["Downtown Core"],["Rochor"],["Downtown Core"],["Downtown Core"],["Queenstown"],["Downtown Core"],["Downtown Core"],["Downtown Core"],["Kallang"],["Downtown Core"],["River Valley"],["River Valley"],["Orchard"],["River Valley"],["River Valley"],["River Valley"],["River Valley"],["River Valley"],["River Valley"],["Toa Payoh"],["Orchard"],["Outram"],["Rochor"],["Downtown Core"],["Novena"],["Novena"],["Novena"],["Novena"],["Novena"],["Outram"],["Bukit Merah"],["Bukit ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="f20d993f-7184-4337-aa98-51e4afc52966" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f20d993f-7184-4337-aa98-51e4afc52966")) {                    Plotly.newPlot(                        "f20d993f-7184-4337-aa98-51e4afc52966",                        [{"customdata":[["River Valley"],["River Valley"],["Novena"],["Novena"],["Rochor"],["Singapore River"],["Kallang"],["Bukit Merah"],["Bukit Merah"],["Bukit Merah"],["Outram"],["Bukit Merah"],["Bukit Merah"],["Bukit Merah"],["Outram"],["River Valley"],["Rochor"],["Kallang"],["Tanglin"],["Downtown Core"],["Singapore River"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["River Valley"],["River Valley"],["Rochor"],["Rochor"],["Singapore River"],["Singapore River"],["River Valley"],["Geylang"],["Tanglin"],["Outram"],["River Valley"],["River Valley"],["River Valley"],["River Valley"],["Singapore River"],["Novena"],["Queenstown"],["River Valley"],["Singapore River"],["Queenstown"],["Rochor"],["Novena"],["Kallang"],["Geylang"],["Orchard"],["Queenstown"],["Bukit Merah"],["Outram"],["Downtown Core"],["Singapore River"],["Tanglin"],["Tanglin"],["Tanglin"],["River Valley"],["Kallang"],["Bukit Merah"],["Novena"],["Bishan"],["River Valley"],["Bukit Merah"],["Geylang"],["Geylang"],["Geylang"],["Bishan"],["Rochor"],["Downtown Core"],["Downtown Core"],["River Valley"],["River Valley"],["Downtown Core"],["Queenstown"],["Singapore River"],["River Valley"],["Bishan"],["Outram"],["Orchard"],["Rochor"],["Rochor"],["Rochor"],["Novena"],["Outram"],["River Valley"],["Bukit Merah"],["Bukit Merah"],["Queenstown"],["Tanglin"],["Downtown Core"],["Tanglin"],["Bukit Merah"],["Novena"],["Novena"],["Novena"],["River Valley"],["River Valley"],["Queenstown"],["River Valley"],["Geylang"],["Geylang"],["Novena"],["River Valley"],["River Valley"],["Downtown Core"],["Downtown Core"],["Downtown Core"],["Downtown Core"],["Singapore River"],["Outram"],["Novena"],["Outram"],["Downtown Core"],["Bukit Merah"],["Bukit Merah"],["Novena"],["Geylang"],["Orchard"],["Orchard"],["Kallang"],["Queenstown"],["River Valley"],["Bukit Merah"],["Novena"],["Queenstown"],["Novena"],["Novena"],["Novena"],["Tanglin"],["Novena"],["Tanglin"],["Novena"],["Novena"],["Geylang"],["Novena"],["Downtown Core"],["Bukit Merah"],["Rochor"],["Rochor"],["Kallang"],["Rochor"],["Geylang"],["Outram"],["Kallang"],["Rochor"],["Downtown Core"],["River Valley"],["Novena"],["Kallang"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Bukit Merah"],["Queenstown"],["Queenstown"],["Downtown Core"],["Outram"],["Novena"],["Bukit Merah"],["Bukit Merah"],["Bukit Merah"],["Downtown Core"],["Tanglin"],["Bukit Merah"],["Downtown Core"],["Queenstown"],["Downtown Core"],["Tanglin"],["Bukit Merah"],["Novena"],["Novena"],["Novena"],["Novena"],["Bishan"],["Downtown Core"],["Novena"],["Bishan"],["Downtown Core"],["Queenstown"],["Bukit Merah"],["Geylang"],["River Valley"],["Rochor"],["Rochor"],["Rochor"],["Rochor"],["Downtown Core"],["Downtown Core"],["Geylang"],["Rochor"],["Rochor"],["Rochor"],["Rochor"],["River Valley"],["Bukit Merah"],["Rochor"],["Rochor"],["Rochor"],["Singapore River"],["Downtown Core"],["Rochor"],["Downtown Core"],["Downtown Core"],["Queenstown"],["Downtown Core"],["Downtown Core"],["Downtown Core"],["Kallang"],["Downtown Core"],["River Valley"],["River Valley"],["Orchard"],["River Valley"],["River Valley"],["River Valley"],["River Valley"],["River Valley"],["River Valley"],["Toa Payoh"],["Orchard"],["Outram"],["Rochor"],["Downtown Core"],["Novena"],["Novena"],["Novena"],["Novena"],["Novena"],["Outram"],["Bukit Merah"],["Bukit ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="874da4fa-f742-4ed5-98d7-a7008cf3e3ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("874da4fa-f742-4ed5-98d7-a7008cf3e3ce")) {                    Plotly.newPlot(                        "874da4fa-f742-4ed5-98d7-a7008cf3e3ce",                        [{"customdata":[["River Valley"],["River Valley"],["Novena"],["Novena"],["Rochor"],["Singapore River"],["Kallang"],["Bukit Merah"],["Bukit Merah"],["Bukit Merah"],["Outram"],["Bukit Merah"],["Bukit Merah"],["Bukit Merah"],["Outram"],["River Valley"],["Rochor"],["Kallang"],["Tanglin"],["Downtown Core"],["Singapore River"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["River Valley"],["River Valley"],["Rochor"],["Rochor"],["Singapore River"],["Singapore River"],["River Valley"],["Geylang"],["Tanglin"],["Outram"],["River Valley"],["River Valley"],["River Valley"],["River Valley"],["Singapore River"],["Novena"],["Queenstown"],["River Valley"],["Singapore River"],["Queenstown"],["Rochor"],["Novena"],["Kallang"],["Geylang"],["Orchard"],["Queenstown"],["Bukit Merah"],["Outram"],["Downtown Core"],["Singapore River"],["Tanglin"],["Tanglin"],["Tanglin"],["River Valley"],["Kallang"],["Bukit Merah"],["Novena"],["Bishan"],["River Valley"],["Bukit Merah"],["Geylang"],["Geylang"],["Geylang"],["Bishan"],["Rochor"],["Downtown Core"],["Downtown Core"],["River Valley"],["River Valley"],["Downtown Core"],["Queenstown"],["Singapore River"],["River Valley"],["Bishan"],["Outram"],["Orchard"],["Rochor"],["Rochor"],["Rochor"],["Novena"],["Outram"],["River Valley"],["Bukit Merah"],["Bukit Merah"],["Queenstown"],["Tanglin"],["Downtown Core"],["Tanglin"],["Bukit Merah"],["Novena"],["Novena"],["Novena"],["River Valley"],["River Valley"],["Queenstown"],["River Valley"],["Geylang"],["Geylang"],["Novena"],["River Valley"],["River Valley"],["Downtown Core"],["Downtown Core"],["Downtown Core"],["Downtown Core"],["Singapore River"],["Outram"],["Novena"],["Outram"],["Downtown Core"],["Bukit Merah"],["Bukit Merah"],["Novena"],["Geylang"],["Orchard"],["Orchard"],["Kallang"],["Queenstown"],["River Valley"],["Bukit Merah"],["Novena"],["Queenstown"],["Novena"],["Novena"],["Novena"],["Tanglin"],["Novena"],["Tanglin"],["Novena"],["Novena"],["Geylang"],["Novena"],["Downtown Core"],["Bukit Merah"],["Rochor"],["Rochor"],["Kallang"],["Rochor"],["Geylang"],["Outram"],["Kallang"],["Rochor"],["Downtown Core"],["River Valley"],["Novena"],["Kallang"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Bukit Merah"],["Queenstown"],["Queenstown"],["Downtown Core"],["Outram"],["Novena"],["Bukit Merah"],["Bukit Merah"],["Bukit Merah"],["Downtown Core"],["Tanglin"],["Bukit Merah"],["Downtown Core"],["Queenstown"],["Downtown Core"],["Tanglin"],["Bukit Merah"],["Novena"],["Novena"],["Novena"],["Novena"],["Bishan"],["Downtown Core"],["Novena"],["Bishan"],["Downtown Core"],["Queenstown"],["Bukit Merah"],["Geylang"],["River Valley"],["Rochor"],["Rochor"],["Rochor"],["Rochor"],["Downtown Core"],["Downtown Core"],["Geylang"],["Rochor"],["Rochor"],["Rochor"],["Rochor"],["River Valley"],["Bukit Merah"],["Rochor"],["Rochor"],["Rochor"],["Singapore River"],["Downtown Core"],["Rochor"],["Downtown Core"],["Downtown Core"],["Queenstown"],["Downtown Core"],["Downtown Core"],["Downtown Core"],["Kallang"],["Downtown Core"],["River Valley"],["River Valley"],["Orchard"],["River Valley"],["River Valley"],["River Valley"],["River Valley"],["River Valley"],["River Valley"],["Toa Payoh"],["Orchard"],["Outram"],["Rochor"],["Downtown Core"],["Novena"],["Novena"],["Novena"],["Novena"],["Novena"],["Outram"],["Bukit Merah"],["Bukit ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="90f86271-9cbb-4cfd-89ee-d532beb74bc1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90f86271-9cbb-4cfd-89ee-d532beb74bc1")) {                    Plotly.newPlot(                        "90f86271-9cbb-4cfd-89ee-d532beb74bc1",                        [{"customdata":[["River Valley"],["River Valley"],["Novena"],["Novena"],["Rochor"],["Singapore River"],["Kallang"],["Bukit Merah"],["Bukit Merah"],["Bukit Merah"],["Outram"],["Bukit Merah"],["Bukit Merah"],["Bukit Merah"],["Outram"],["River Valley"],["Rochor"],["Kallang"],["Tanglin"],["Downtown Core"],["Singapore River"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["River Valley"],["River Valley"],["Rochor"],["Rochor"],["Singapore River"],["Singapore River"],["River Valley"],["Geylang"],["Tanglin"],["Outram"],["River Valley"],["River Valley"],["River Valley"],["River Valley"],["Singapore River"],["Novena"],["Queenstown"],["River Valley"],["Singapore River"],["Queenstown"],["Rochor"],["Novena"],["Kallang"],["Geylang"],["Orchard"],["Queenstown"],["Bukit Merah"],["Outram"],["Downtown Core"],["Singapore River"],["Tanglin"],["Tanglin"],["Tanglin"],["River Valley"],["Kallang"],["Bukit Merah"],["Novena"],["Bishan"],["River Valley"],["Bukit Merah"],["Geylang"],["Geylang"],["Geylang"],["Bishan"],["Rochor"],["Downtown Core"],["Downtown Core"],["River Valley"],["River Valley"],["Downtown Core"],["Queenstown"],["Singapore River"],["River Valley"],["Bishan"],["Outram"],["Orchard"],["Rochor"],["Rochor"],["Rochor"],["Novena"],["Outram"],["River Valley"],["Bukit Merah"],["Bukit Merah"],["Queenstown"],["Tanglin"],["Downtown Core"],["Tanglin"],["Bukit Merah"],["Novena"],["Novena"],["Novena"],["River Valley"],["River Valley"],["Queenstown"],["River Valley"],["Geylang"],["Geylang"],["Novena"],["River Valley"],["River Valley"],["Downtown Core"],["Downtown Core"],["Downtown Core"],["Downtown Core"],["Singapore River"],["Outram"],["Novena"],["Outram"],["Downtown Core"],["Bukit Merah"],["Bukit Merah"],["Novena"],["Geylang"],["Orchard"],["Orchard"],["Kallang"],["Queenstown"],["River Valley"],["Bukit Merah"],["Novena"],["Queenstown"],["Novena"],["Novena"],["Novena"],["Tanglin"],["Novena"],["Tanglin"],["Novena"],["Novena"],["Geylang"],["Novena"],["Downtown Core"],["Bukit Merah"],["Rochor"],["Rochor"],["Kallang"],["Rochor"],["Geylang"],["Outram"],["Kallang"],["Rochor"],["Downtown Core"],["River Valley"],["Novena"],["Kallang"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Bukit Merah"],["Queenstown"],["Queenstown"],["Downtown Core"],["Outram"],["Novena"],["Bukit Merah"],["Bukit Merah"],["Bukit Merah"],["Downtown Core"],["Tanglin"],["Bukit Merah"],["Downtown Core"],["Queenstown"],["Downtown Core"],["Tanglin"],["Bukit Merah"],["Novena"],["Novena"],["Novena"],["Novena"],["Bishan"],["Downtown Core"],["Novena"],["Bishan"],["Downtown Core"],["Queenstown"],["Bukit Merah"],["Geylang"],["River Valley"],["Rochor"],["Rochor"],["Rochor"],["Rochor"],["Downtown Core"],["Downtown Core"],["Geylang"],["Rochor"],["Rochor"],["Rochor"],["Rochor"],["River Valley"],["Bukit Merah"],["Rochor"],["Rochor"],["Rochor"],["Singapore River"],["Downtown Core"],["Rochor"],["Downtown Core"],["Downtown Core"],["Queenstown"],["Downtown Core"],["Downtown Core"],["Downtown Core"],["Kallang"],["Downtown Core"],["River Valley"],["River Valley"],["Orchard"],["River Valley"],["River Valley"],["River Valley"],["River Valley"],["River Valley"],["River Valley"],["Toa Payoh"],["Orchard"],["Outram"],["Rochor"],["Downtown Core"],["Novena"],["Novena"],["Novena"],["Novena"],["Novena"],["Outram"],["Bukit Merah"],["Bukit ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a1214e56-f4c2-47ff-b1ab-8472eeee7e64" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1214e56-f4c2-47ff-b1ab-8472eeee7e64")) {                    Plotly.newPlot(                        "a1214e56-f4c2-47ff-b1ab-8472eeee7e64",                        [{"customdata":[["River Valley"],["River Valley"],["Novena"],["Novena"],["Rochor"],["Singapore River"],["Kallang"],["Bukit Merah"],["Bukit Merah"],["Bukit Merah"],["Outram"],["Bukit Merah"],["Bukit Merah"],["Bukit Merah"],["Outram"],["River Valley"],["Rochor"],["Kallang"],["Tanglin"],["Downtown Core"],["Singapore River"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["River Valley"],["River Valley"],["Rochor"],["Rochor"],["Singapore River"],["Singapore River"],["River Valley"],["Geylang"],["Tanglin"],["Outram"],["River Valley"],["River Valley"],["River Valley"],["River Valley"],["Singapore River"],["Novena"],["Queenstown"],["River Valley"],["Singapore River"],["Queenstown"],["Rochor"],["Novena"],["Kallang"],["Geylang"],["Orchard"],["Queenstown"],["Bukit Merah"],["Outram"],["Downtown Core"],["Singapore River"],["Tanglin"],["Tanglin"],["Tanglin"],["River Valley"],["Kallang"],["Bukit Merah"],["Novena"],["Bishan"],["River Valley"],["Bukit Merah"],["Geylang"],["Geylang"],["Geylang"],["Bishan"],["Rochor"],["Downtown Core"],["Downtown Core"],["River Valley"],["River Valley"],["Downtown Core"],["Queenstown"],["Singapore River"],["River Valley"],["Bishan"],["Outram"],["Orchard"],["Rochor"],["Rochor"],["Rochor"],["Novena"],["Outram"],["River Valley"],["Bukit Merah"],["Bukit Merah"],["Queenstown"],["Tanglin"],["Downtown Core"],["Tanglin"],["Bukit Merah"],["Novena"],["Novena"],["Novena"],["River Valley"],["River Valley"],["Queenstown"],["River Valley"],["Geylang"],["Geylang"],["Novena"],["River Valley"],["River Valley"],["Downtown Core"],["Downtown Core"],["Downtown Core"],["Downtown Core"],["Singapore River"],["Outram"],["Novena"],["Outram"],["Downtown Core"],["Bukit Merah"],["Bukit Merah"],["Novena"],["Geylang"],["Orchard"],["Orchard"],["Kallang"],["Queenstown"],["River Valley"],["Bukit Merah"],["Novena"],["Queenstown"],["Novena"],["Novena"],["Novena"],["Tanglin"],["Novena"],["Tanglin"],["Novena"],["Novena"],["Geylang"],["Novena"],["Downtown Core"],["Bukit Merah"],["Rochor"],["Rochor"],["Kallang"],["Rochor"],["Geylang"],["Outram"],["Kallang"],["Rochor"],["Downtown Core"],["River Valley"],["Novena"],["Kallang"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Queenstown"],["Bukit Merah"],["Queenstown"],["Queenstown"],["Downtown Core"],["Outram"],["Novena"],["Bukit Merah"],["Bukit Merah"],["Bukit Merah"],["Downtown Core"],["Tanglin"],["Bukit Merah"],["Downtown Core"],["Queenstown"],["Downtown Core"],["Tanglin"],["Bukit Merah"],["Novena"],["Novena"],["Novena"],["Novena"],["Bishan"],["Downtown Core"],["Novena"],["Bishan"],["Downtown Core"],["Queenstown"],["Bukit Merah"],["Geylang"],["River Valley"],["Rochor"],["Rochor"],["Rochor"],["Rochor"],["Downtown Core"],["Downtown Core"],["Geylang"],["Rochor"],["Rochor"],["Rochor"],["Rochor"],["River Valley"],["Bukit Merah"],["Rochor"],["Rochor"],["Rochor"],["Singapore River"],["Downtown Core"],["Rochor"],["Downtown Core"],["Downtown Core"],["Queenstown"],["Downtown Core"],["Downtown Core"],["Downtown Core"],["Kallang"],["Downtown Core"],["River Valley"],["River Valley"],["Orchard"],["River Valley"],["River Valley"],["River Valley"],["River Valley"],["River Valley"],["River Valley"],["Toa Payoh"],["Orchard"],["Outram"],["Rochor"],["Downtown Core"],["Novena"],["Novena"],["Novena"],["Novena"],["Novena"],["Outram"],["Bukit Merah"],["Bukit ...

# %% [markdown]
# ## Corelation Price and Room Type

# %%
corr = df[['room_type', 'total_review']].groupby(['room_type']).mean()

# membuat heatmap

plt.figure(figsize = (12,10))

ax =sns.heatmap(corr,annot=True)

font = {'family': 'Arial', 'size': 15}

ax.tick_params(axis='y', labelsize=15)
ax.tick_params(axis='x', labelsize=15)
plt.show()

# %%
harga_room_ng = df.groupby(['neighbourhood_group', 'room_type'])['price'].mean().reset_index()
harga_room_ng
# Out:
#    neighbourhood_group        room_type       price
# 0       Central Region  Entire home/apt  168.885417
# 1       Central Region       Hotel room  101.166667
# 2       Central Region     Private room   88.025292
# 3       Central Region      Shared room   59.761194
# 4          East Region  Entire home/apt  156.571429
# 5          East Region     Private room  106.573333
# 6         North Region  Entire home/apt   70.095153
# 7         North Region       Hotel room   54.272727
# 8         North Region     Private room   61.602740
# 9         North Region      Shared room   23.000000
# 10   North-East Region  Entire home/apt  105.571429
# 11   North-East Region     Private room   87.800000
# 12   North-East Region      Shared room  130.000000
# 13         West Region  Entire home/apt   69.052846
# 14         West Region     Private room   69.921875
# 15         West Region      Shared room   71.000000

# %%
# Membuat contoh data frame
# Create the bar chart
harga_room_ng = harga_room_ng.sort_values('price')
plot_price_room_type_ng = px.bar(harga_room_ng, x="neighbourhood_group", y="price", barmode = 'group',color="room_type", template = 'ggplot2')

plot_price_room_type_ng.update_layout(title = '<b>Harga Room Type Pada Neigbourhood Group<b>', title_font = dict(size = 20, family = 'arial', color = 'black')
                              )

plot_price_room_type_ng.update_xaxes(title = "Room Type", title_font = dict(size = 18, color = "black", family = 'arial'))
plot_price_room_type_ng.update_yaxes(title = 'Price', title_font = dict(size = 18, color = 'black', family = 'arial'))

# Show the chart
plot_price_room_type_ng.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="bd1462aa-ea57-473f-867d-712d68082f74" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd1462aa-ea57-473f-867d-712d68082f74")) {                    Plotly.newPlot(                        "bd1462aa-ea57-473f-867d-712d68082f74",                        [{"alignmentgroup":"True","hovertemplate":"room_type=Shared room<br>neighbourhood_group=%{x}<br>price=%{y}<extra></extra>","legendgroup":"Shared room","marker":{"color":"#F8766D","pattern":{"shape":""}},"name":"Shared room","offsetgroup":"Shared room","orientation":"v","showlegend":true,"textposition":"auto","x":["North Region","Central Region","West Region","North-East Region"],"xaxis":"x","y":[23.0,59.76119402985075,71.0,130.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"room_type=Hotel room<br>neighbourhood_group=%{x}<br>price=%{y}<extra></extra>","legendgroup":"Hotel room","marker":{"color":"#A3A500","pattern":{"shape":""}},"name":"Hotel room","offsetgroup":"Hotel room","orientation":"v","showlegend":true,"textposition":"auto","x":["North Region","Central Region"],"xaxis":"x","y":[54.27272727272727,101.16666666666667],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"room_type=Private room<br>neighbourhood_group=%{x}<br>price=%{y}<extra></extra>","legendgroup":"Private room","marker":{"color":"#00BF7D","pattern":{"shape":""}},"name":"Private room","offsetgroup":"Private room","orientation":"v","showlegend":true,"textposition":"auto","x":["North Region","West Region","North-East Region","Central Region","East Region"],"xaxis":"x","y":[61.602739726027394,69.921875,87.8,88.02529182879377,106.57333333333334],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"room_type=Entire home/apt<br>neighbourhood_group=%{x}<br>price=%{y}<extra></extra>","legendgroup":"Entire home/apt","marker":{"color":"#00B0F6","pattern":{"shape":""}},"name":"Entire home/apt","offsetgroup":"Entire home/apt","orientation":"v","showlegend":true,"textposition":"auto","x":["West Region","North Region","North-East Region","East Region","Central Region"],"xaxis":"x","y":[69.05284552845528,70.0951526032316,105.57142857142857,156.57142857142858,168.88541666666666],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(51,51,51)"},"error_y":{"color":"rgb(51,51,51)"},"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"baxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatma ...

# %% [markdown]
# ## Distribusi Pengunjung

# %%
top_review_listing_room_ng = df.groupby(['neighbourhood_group', 'room_type'])['total_review'].sum().reset_index()
top_review_listing_room_ng.sort_values('total_review')

plot_top_review_room_ng = px.bar(top_review_listing_room_ng, x = 'neighbourhood_group', y = 'total_review', color = 'room_type', barmode = 'group', orientation = 'v', opacity = 1, template = 'ggplot2')

plot_top_review_room_ng.update_layout(title = '<b> Distribusi Review Berdasarkan Room Type Pada setiap Neighbourhood Group<b>', title_font = dict(size = 20, color = 'black', family = 'arial'))
plot_top_review_room_ng.update_xaxes(title = 'Neighbourhood Group', title_font = dict(size = 18, color = 'black', family = 'arial'))
plot_top_review_room_ng.update_yaxes(title = 'Jumlah Review', title_font = dict(size = 18, color = 'black', family = 'arial'))

plot_top_review_room_ng.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="7c6f5655-ac10-49a4-aaf2-b77691231ee7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c6f5655-ac10-49a4-aaf2-b77691231ee7")) {                    Plotly.newPlot(                        "7c6f5655-ac10-49a4-aaf2-b77691231ee7",                        [{"alignmentgroup":"True","hovertemplate":"room_type=Entire home/apt<br>neighbourhood_group=%{x}<br>total_review=%{y}<extra></extra>","legendgroup":"Entire home/apt","marker":{"color":"#F8766D","opacity":1,"pattern":{"shape":""}},"name":"Entire home/apt","offsetgroup":"Entire home/apt","orientation":"v","showlegend":true,"textposition":"auto","x":["Central Region","East Region","North Region","North-East Region","West Region"],"xaxis":"x","y":[4686,402,20948,255,4509],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"room_type=Hotel room<br>neighbourhood_group=%{x}<br>total_review=%{y}<extra></extra>","legendgroup":"Hotel room","marker":{"color":"#A3A500","opacity":1,"pattern":{"shape":""}},"name":"Hotel room","offsetgroup":"Hotel room","orientation":"v","showlegend":true,"textposition":"auto","x":["Central Region","North Region"],"xaxis":"x","y":[1470,337],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"room_type=Private room<br>neighbourhood_group=%{x}<br>total_review=%{y}<extra></extra>","legendgroup":"Private room","marker":{"color":"#00BF7D","opacity":1,"pattern":{"shape":""}},"name":"Private room","offsetgroup":"Private room","orientation":"v","showlegend":true,"textposition":"auto","x":["Central Region","East Region","North Region","North-East Region","West Region"],"xaxis":"x","y":[7448,1473,963,738,632],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"room_type=Shared room<br>neighbourhood_group=%{x}<br>total_review=%{y}<extra></extra>","legendgroup":"Shared room","marker":{"color":"#00B0F6","opacity":1,"pattern":{"shape":""}},"name":"Shared room","offsetgroup":"Shared room","orientation":"v","showlegend":true,"textposition":"auto","x":["Central Region","North Region","North-East Region","West Region"],"xaxis":"x","y":[714,12,5,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(51,51,51)"},"error_y":{"color":"rgb(51,51,51)"},"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"baxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","tic ...

# %%
data_east['neighbourhood'].nunique()
# Out:
# 3

# %%
def plot_pie_review_per_neighbourhood(data):
  title = data.reset_index().at[0,'neighbourhood_group']
  if data['neighbourhood'].nunique() > 3:
     # group data into neighbourhood and select 4 highhest total_reviews
     sum_review_neighbourhood = data.groupby('neighbourhood')['total_review'].sum().nlargest()
     # sum of top 4 total review
     top_review = sum_review_neighbourhood.sum()
     # find sum review for other top review
     other_sum_neighbourhood = data['total_review'].sum() - top_review
     
     # find count of variabel other total review (count for data['neighbourhood'] - count for variabel top 4 sum_review_neighbourhood)
     count_other = data['neighbourhood'].nunique() - sum_review_neighbourhood.nunique()
     
     # make data for other_sum_neighbourhood
     other_sum_neighbourhood = (other_sum_neighbourhood / count_other).astype(int)
     
     #add other_sum_neighbourhood to data sum_review_neighbourhood 
     sum_review_neighbourhood['other'] = other_sum_neighbourhood
     sum_review_neighbourhood.sort_values(ascending = False)
     
     # make pie plot 
     fig = px.pie(sum_review_neighbourhood,
               values = sum_review_neighbourhood,
               names = sum_review_neighbourhood.index,
               color = sum_review_neighbourhood.index,
               hole = 0.5)
     fig.update_layout(title = "<b> Distribution Pengunjung Listing <br> Per Neighbourhood </b>", title_font = dict(size = 20, color = 'black', family = 'arial'))
     fig.update_traces(textposition = 'outside', textfont = dict(size = 15, color = 'black', family = 'arial'), textinfo = 'label+percent')
     fig.add_annotation(text = f"<b> {title} <b>", showarrow = False, font = dict(size = 18, color = 'black', family = 'arial'))
     fig.show()
  
  else: 
    sum_review_neighbourhood = data.groupby('neighbourhood')['total_review'].sum()

    fig = px.pie(sum_review_neighbourhood,
               values = sum_review_neighbourhood,
               names = sum_review_neighbourhood.index,
               color = sum_review_neighbourhood.index,
               hole = 0.5)
    fig.update_layout(title = "<b> Distribution Pengunjung Listing <br> Per Neighbourhood </b>", title_font = dict(size = 20, color = 'black', family = 'arial'))
    fig.update_traces(textposition = 'outside', textfont = dict(size = 15, color = 'black', family = 'arial'), textinfo = 'label+percent')
    fig.add_annotation(text = f"<b> {title} <b>", showarrow = False, font = dict(size = 18, color = 'black', family = 'arial'))
    fig.show()

# %%
plot_pie_review_per_neighbourhood(data_central)
plot_pie_review_per_neighbourhood(data_east)
plot_pie_review_per_neighbourhood(data_west)
plot_pie_review_per_neighbourhood(data_north)
plot_pie_review_per_neighbourhood(data_north_east)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ae7e4d50-f5a5-40c2-8e83-e6758145dc0c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae7e4d50-f5a5-40c2-8e83-e6758145dc0c")) {                    Plotly.newPlot(                        "ae7e4d50-f5a5-40c2-8e83-e6758145dc0c",                        [{"customdata":[["Kallang"],["Rochor"],["Geylang"],["Outram"],["Downtown Core"],["other"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"neighbourhood=%{customdata[0]}<br>value=%{value}<extra></extra>","labels":["Kallang","Rochor","Geylang","Outram","Downtown Core","other"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B","#00cc96","#ab63fa","#FFA15A","#19d3f3"]},"name":"","showlegend":true,"values":[2915,2198,1685,1669,1636,324],"type":"pie","textfont":{"color":"black","family":"arial","size":15},"textinfo":"label+percent","textposition":"outside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="4cd751ee-9f4b-4e99-a603-880ae2f5cef1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4cd751ee-9f4b-4e99-a603-880ae2f5cef1")) {                    Plotly.newPlot(                        "4cd751ee-9f4b-4e99-a603-880ae2f5cef1",                        [{"customdata":[["Bedok"],["Pasir Ris"],["Tampines"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"neighbourhood=%{customdata[0]}<br>value=%{value}<extra></extra>","labels":["Bedok","Pasir Ris","Tampines"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B","#00cc96"]},"name":"","showlegend":true,"values":[1088,70,717],"type":"pie","textfont":{"color":"black","family":"arial","size":15},"textinfo":"label+percent","textposition":"outside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"sc ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c17f17a6-e893-476a-a518-08cad7de98e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c17f17a6-e893-476a-a518-08cad7de98e8")) {                    Plotly.newPlot(                        "c17f17a6-e893-476a-a518-08cad7de98e8",                        [{"customdata":[["Western Water Catchment"],["Jurong West"],["Jurong East"],["Clementi"],["Choa Chu Kang"],["other"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"neighbourhood=%{customdata[0]}<br>value=%{value}<extra></extra>","labels":["Western Water Catchment","Jurong West","Jurong East","Clementi","Choa Chu Kang","other"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B","#00cc96","#ab63fa","#FFA15A","#19d3f3"]},"name":"","showlegend":true,"values":[4516,296,117,108,85,10],"type":"pie","textfont":{"color":"black","family":"arial","size":15},"textinfo":"label+percent","textposition":"outside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="896d435d-f3fb-4cb8-8f90-7d2e44c13f44" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("896d435d-f3fb-4cb8-8f90-7d2e44c13f44")) {                    Plotly.newPlot(                        "896d435d-f3fb-4cb8-8f90-7d2e44c13f44",                        [{"customdata":[["Woodlands"],["Lim Chu Kang"],["Sungei Kadut"],["Sembawang"],["Yishun"],["other"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"neighbourhood=%{customdata[0]}<br>value=%{value}<extra></extra>","labels":["Woodlands","Lim Chu Kang","Sungei Kadut","Sembawang","Yishun","other"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B","#00cc96","#ab63fa","#FFA15A","#19d3f3"]},"name":"","showlegend":true,"values":[19749,2123,305,61,20,2],"type":"pie","textfont":{"color":"black","family":"arial","size":15},"textinfo":"label+percent","textposition":"outside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"} ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="e4c5c5ff-9a49-4ff5-aff3-791ab3733efc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e4c5c5ff-9a49-4ff5-aff3-791ab3733efc")) {                    Plotly.newPlot(                        "e4c5c5ff-9a49-4ff5-aff3-791ab3733efc",                        [{"customdata":[["Serangoon"],["Hougang"],["Punggol"],["Sengkang"],["Ang Mo Kio"],["other"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"neighbourhood=%{customdata[0]}<br>value=%{value}<extra></extra>","labels":["Serangoon","Hougang","Punggol","Sengkang","Ang Mo Kio","other"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B","#00cc96","#ab63fa","#FFA15A","#19d3f3"]},"name":"","showlegend":true,"values":[516,290,164,17,9,2],"type":"pie","textfont":{"color":"black","family":"arial","size":15},"textinfo":"label+percent","textposition":"outside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line": ...

# %% [markdown]
# ## Total Review Dibawah dan diatas Rata-rata

# %%
mean_total_review_ng = df.dropna().groupby('neighbourhood_group')['total_review'].mean().reset_index()

df['type_total_review'] = df.apply(lambda row: 'Above Mean' if row['total_review']> mean_total_review_ng.loc[mean_total_review_ng['neighbourhood_group'] == row ['neighbourhood_group'], 'total_review'].iloc[0] else  'Below Mean', axis = 1)

plot_mean_total_review = px.scatter(df, x= 'neighbourhood_group', y = 'total_review', color = 'type_total_review')
plot_mean_total_review.add_hline(y = mean_total_review_ng['total_review'].mean(), line_dash = 'dash', line_color = 'black',  annotation_text = "Mean Total Review")
plot_mean_total_review.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="77b90c3b-3353-4930-b56e-6894c21c61e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77b90c3b-3353-4930-b56e-6894c21c61e5")) {                    Plotly.newPlot(                        "77b90c3b-3353-4930-b56e-6894c21c61e5",                        [{"hovertemplate":"type_total_review=Below Mean<br>neighbourhood_group=%{x}<br>total_review=%{y}<extra></extra>","legendgroup":"Below Mean","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Below Mean","showlegend":true,"x":["North Region","North Region","North Region","North Region","North Region","North Region","West Region","North Region","Central Region","Central Region","Central Region","Central Region","North Region","West Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","North Region","North Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","North Region","Central Region","North Region","Central Region","North Region","Central Region","North Region","North Region","Central Region","West Region","North Region","Central Region","Central Region","Central Region","North Region","Central Region","North Region","North Region","North Region","North Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","North Region","Central Region","Central Region","Central Region","North Region","West Region","Central Region","West Region","West Region","North Region","West Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","West Region","North Region","North Region","North Region","Central Region","West Region","North Region","North Region","Central Region","Central Region","Central Region","Central Region","North Region","North Region","Central Region","North Region","Central Region","Central Region","North Region","West Region","North Region","North-East Region","West Region","North Region","West Region","West Region","Central Region","West Region","North Region","Central Region","Central Region","Central Region","North Region","North Region","North Region","Central Region","North Region","West Region","West Region","West Region","North Region","West Region","North Region","North Region","West Region","Central Region","Central Region","North Region","West Region","West Region","West Region","West Region","North Region","West Region","West Region","West Region","West Region","West Region","West Region","North Region","West Region","West Region","West Region","West Region","West Region","West Region","West Region","West Region","West Region","Central Region","North Region","Central Region","Central Region","Central Region","Central Region","Central Region","North Region","Central Region","Central Region","West Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","Central Region","West Region","North Region","Central Region","North Region","East Region","Central Region","North Region","North Region","Central Region","West Region","West Region","West Region","West Region","West Region","West Region","West Region","West Region","West Region","West Region","North-East Region","North Region","North Region","Central Region","West Region","West Region","Central Region","West Region","Central Region","Central Region","Central Region","Central Region","North Region","North Region","West Region","Central Region","West Region","Central Region","North Region","West Region","West Region","No ...

# %%
grouped_type_total_review_ng = df.dropna().groupby(['neighbourhood_group', 'type_total_review']).size().reset_index(name ='counts')

plot_type_review = px.bar(grouped_type_total_review_ng, x = 'neighbourhood_group',
                          y = 'counts', color = 'type_total_review', 
                          barmode = 'group', 
                          labels = {'type_total_review' : 'Status Review', 'counts' : 'Jumlah'}, template = 'ggplot2')
plot_type_review.update_layout(title = '<b>Jumlah Listing Dengan Kunjungan Di Bawah Rata-rata dan Di Atas Rata-rata<b>', title_font = dict(size = 20, color= 'black', family = 'arial'))
plot_type_review.update_xaxes(title = 'Neighbourhood Group', title_font= dict(size = 18, color = 'black', family = 'arial'))
plot_type_review.update_yaxes(title = 'Jumlah', title_font = dict(size = 18, color = 'black', family = 'arial'))

plot_type_review.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="e36e7150-33dd-40bc-8322-146b8af4a074" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e36e7150-33dd-40bc-8322-146b8af4a074")) {                    Plotly.newPlot(                        "e36e7150-33dd-40bc-8322-146b8af4a074",                        [{"alignmentgroup":"True","hovertemplate":"Status Review=Above Mean<br>neighbourhood_group=%{x}<br>Jumlah=%{y}<extra></extra>","legendgroup":"Above Mean","marker":{"color":"#F8766D","pattern":{"shape":""}},"name":"Above Mean","offsetgroup":"Above Mean","orientation":"v","showlegend":true,"textposition":"auto","x":["Central Region","East Region","North Region","North-East Region","West Region"],"xaxis":"x","y":[200,21,174,13,97],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Status Review=Below Mean<br>neighbourhood_group=%{x}<br>Jumlah=%{y}<extra></extra>","legendgroup":"Below Mean","marker":{"color":"#A3A500","pattern":{"shape":""}},"name":"Below Mean","offsetgroup":"Below Mean","orientation":"v","showlegend":true,"textposition":"auto","x":["Central Region","East Region","North Region","North-East Region","West Region"],"xaxis":"x","y":[765,68,468,30,214],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(51,51,51)"},"error_y":{"color":"rgb(51,51,51)"},"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"baxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scatter3d"}],"scat ...

# %% [markdown]
# ## Listing After Covid 19

# %%
df = df.dropna()
# mengubah tipe data kolom 'last_review' menjadi datetime
df['last_review'] = pd.to_datetime(df['last_review'])

# membuat kolom baru dengan kondisi yang diinginkan
df['status_after_covid'] = df['last_review'].apply(lambda x: 'active' if x > pd.Timestamp(2019,1,23) else 'not active')


data_before_after = df.groupby('status_after_covid')['status_after_covid'].count()
data_before_after
pie_before_after_covid = px.pie(data_before_after, values = data_before_after, names = ['Active', 'Not Active'], template = 'ggplot2', color_discrete_sequence= ['#19A7CE', '#146C94'])

pie_before_after_covid.update_layout(title = '<b>Perbandingan Listing Yang Aktif Sesudah dan Sebelum Covid 19<b>', title_font = dict(size = 20, color = 'black', family = 'arial'))
pie_before_after_covid.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ac313dab-bd86-42bd-8699-f3ed4e4c09f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac313dab-bd86-42bd-8699-f3ed4e4c09f1")) {                    Plotly.newPlot(                        "ac313dab-bd86-42bd-8699-f3ed4e4c09f1",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["Active","Not Active"],"legendgroup":"","name":"","showlegend":true,"values":[1930,120],"type":"pie"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(51,51,51)"},"error_y":{"color":"rgb(51,51,51)"},"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"baxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scattergl"}],"scattermapbox":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scattermapbox"}],"scatterpolargl":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scatterpolar ...
#
# var gd = document.getElementById('ac313dab-bd86-42bd-8699-f3ed4e4c09f1');
# var x = new Mutation

# %%
data_line = dataset.dropna().sort_values('review_date')
data_line
# Out:
#                        id                                               name  \
# 5516             12043317                     Vacation home at Taman Pelangi
# 9211              8119347                 Excellent accommodation & location
# 835              14530157      65m2 cozy condo with pool near Paya Lebar MRT
# 840              12484261   City room 5mins to Haji, near Suntec/MBS/Merlion
# 1462              5889741                   Entire Home in the Heart of City
# ...                   ...                                                ...
# 4447              4008423             City 1-Pax Private Room, Shared Toilet
# 27239            32773291     ★Astonishing "270" Unblock Sea view Danga Bay★
# 41642  580226596963352685       【R&F】The Vintage Collective Suite byⓗⓢ #NEW#
# 48985            45962749                        3BR Urban Living in Orchard
# 3793   640245872878209652  Lovely suites w JacuzziTub/InfinityPool/Seavie...
#
#          host_id  host_name neighbourhood  latitude   longitude  \
# 5516    21825042       Wins     Woodlands  1.472550  103.775180
# 9211    31125377  Siong Yew     Woodlands  1.460880  103.767160
# 835      3162951    Nicolas       Geylang  1.314700  103.892890
# 840      3234859         Sk        Rochor  1.302490  103.860350
# 1462     5365111          Y        Rochor  1.301530  103.853440
# ...          ...        ...           ...       ...         ...
# 4447    12067440      Peggy       Kallang  1.311790  103.860020
# 27239  136838494       Joey  Lim Chu Kang  1.464481  103.726707
# 41642  260813040     Havona     Woodlands  1.460850  103.770540
# 48985  372124974      Karen       Orchard  1.300650  103.841750
# 3793     9624622      Catie     Woodlands  1.468420  103.771460
#
#              room_type  price  minimum_nights  availability_365  \
# 5516   Entire home/apt    244               1               364
# 9211   Entire home/apt     50               2               205
# 835    Entire home/apt     89             365                 0
# 840       Private room     64              92                 0
# 1462   Entire home/apt    173              92               121
# ...                ...    ...             ...               ...
# 4447      Private room     62               1               348
# 27239  Entire home/apt    126               1                85
# 41642  Entire home/apt     43               1                76
# 48985  Entire home/apt   1073               6                 5
# 3793   Entire home/apt     73               1               365
#
#       neighbourhood_group review_date
# 5516         North Region  2018-01-01
# 9211         North Region  2018-01-01
# 835        Central Region  2018-01-01
# 840        Central Region  2018-01-01
# 1462       Central Region  2018-01-01
# ...                   ...         ...
# 4447       Central Region  2022-09-22
# 27239        North Region  2022-09-22
# 41642        North Region  2022-09-22
# 48985      Central Region  2022-09-22
# 3793         North Region  2022-09-22
#
# [49695 rows x 13 columns]

# %% [markdown]
# ## Kunjungan dari tahun ke tahun

# %%
date_agg_data = ps.sqldf(''' select  review_date, count(review_date) as total_review
                             from dataset
                             group by review_date
                             order by review_date
                          ''')
date_agg_data

date_agg_data['review_date'] = pd.to_datetime(date_agg_data['review_date'])
date_agg_data['date_month'] = date_agg_data['review_date'].apply(lambda x: datetime.strftime(x, '%Y-%m'))



monthly_agg_data = date_agg_data.groupby('date_month')['total_review'].sum().reset_index()
monthly_agg_data
# Out:
#    date_month  total_review
# 0     2018-01           447
# 1     2018-02           432
# 2     2018-03           507
# 3     2018-04           527
# 4     2018-05           548
# 5     2018-06           603
# 6     2018-07           705
# 7     2018-08           698
# 8     2018-09           726
# 9     2018-10           672
# 10    2018-11           686
# 11    2018-12           942
# 12    2019-01           910
# 13    2019-02           877
# 14    2019-03          1006
# 15    2019-04           928
# 16    2019-05           962
# 17    2019-06          1127
# 18    2019-07          1228
# 19    2019-08          1381
# 20    2019-09          1357
# 21    2019-10          1277
# 22    2019-11          1370
# 23    2019-12          1846
# 24    2020-01          1684
# 25    2020-02          1059
# 26    2020-03           814
# 27    2020-04           180
# 28    2020-05           331
# 29    2020-06           388
# 30    2020-07           546
# 31    2020-08           525
# 32    2020-09           520
# 33    2020-10           485
# 34    2020-11           403
# 35    2020-12           659
# 36    2021-01           431
# 37    2021-02           395
# 38    2021-03           551
# 39    2021-04           509
# 40    2021-05           475
# 41    2021-06           363
# 42    2021-07           370
# 43    2021-08           398
# 44    2021-09           480
# 45    2021-10           701
# 46    2021-11           789
# 47    2021-12          1150
# 48    2022-01           873
# 49    2022-02           834
# 50    2022-03           810
# 51    2022-04          1084
# 52    2022-05          1970
# 53    2022-06          2057
# 54    2022-07          2276
# 55    2022-08          2331
# 56    2022-09          1492

# %%
plot_date_review = px.line(monthly_agg_data,x = 'date_month', y = 'total_review', markers = True)

plot_date_review.update_layout(title = '<b>Penyewaan Listing di Airbnb Singapore dari tahun 2018 - 2022<b>', title_font = dict(size = 20, color = 'black', family = 'arial'), title_x = 0.5, template = 'ggplot2')
plot_date_review.update_xaxes(title = 'Date', title_font = dict(size = 18, color = 'black', family = 'arial'))
plot_date_review.update_yaxes(title = 'Jumlah', title_font = dict(size = 18, color = 'black', family = 'arial'))
plot_date_review.add_annotation(text = 'Terjadi Penurunan yang tajam dari Desember-April', x = '2020-03', y = '2000', showarrow = False, font = dict(size = 14, color = 'black', family = 'arial'))
plot_date_review.add_annotation(text = 'Terjadi Lonjakan yang cukup tajam', x = '2022-05', y = '700', showarrow = False, font = dict(size = 14, color = ' black', family = 'arial'))
plot_date_review.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="f3cc9ce2-197a-4195-95c2-370aa9a8eb91" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3cc9ce2-197a-4195-95c2-370aa9a8eb91")) {                    Plotly.newPlot(                        "f3cc9ce2-197a-4195-95c2-370aa9a8eb91",                        [{"hovertemplate":"date_month=%{x}<br>total_review=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2018-01","2018-02","2018-03","2018-04","2018-05","2018-06","2018-07","2018-08","2018-09","2018-10","2018-11","2018-12","2019-01","2019-02","2019-03","2019-04","2019-05","2019-06","2019-07","2019-08","2019-09","2019-10","2019-11","2019-12","2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10","2020-11","2020-12","2021-01","2021-02","2021-03","2021-04","2021-05","2021-06","2021-07","2021-08","2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06","2022-07","2022-08","2022-09"],"xaxis":"x","y":[447,432,507,527,548,603,705,698,726,672,686,942,910,877,1006,928,962,1127,1228,1381,1357,1277,1370,1846,1684,1059,814,180,331,388,546,525,520,485,403,659,431,395,551,509,475,363,370,398,480,701,789,1150,873,834,810,1084,1970,2057,2276,2331,1492],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(51,51,51)"},"error_y":{"color":"rgb(51,51,51)"},"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"baxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"tickc ...

# %%
df
# Out:
#                       id                                               name  \
# 1050  635937428811021850         New Cozy Studio Apt@ Somerset/Orchard Area
# 1052  549186561382713865  NEW Deluxe Comfy Studio Apt @Orchard/Somerset ...
# 1061            54205551      Serviced apartment- Unique Penthhouse in city
# 1062            54204802        Novena Serviced Apartment - Luxe Penthhouse
# 1067            23045739  Executive SG Clean Apartment in Singapore Central
# ...                  ...                                                ...
# 4148            37302795              DRAGON INN PREMIUM HOTEL (JB) SDN BHD
# 4153            38224254          [Bungalow Homestay] Johor Bahru Bedroom 4
# 4154            29837000             R&F Princess Cove common room for rent
# 4155            15544996       Bedroom in JB with quick access to Singapore
# 4156            53190609                                  Yaya's Staycation
#
#         host_id     host_name neighbourhood  latitude   longitude  \
# 1050   10248444     Binh Chan  River Valley  1.294390  103.838610
# 1052   10248444     Binh Chan  River Valley  1.294800  103.838410
# 1061   24496358     Katherine        Novena  1.318524  103.847511
# 1062   68059127           Wei        Novena  1.318524  103.847511
# 1067  148161755           Jan        Rochor  1.298060  103.852570
# ...         ...           ...           ...       ...         ...
# 4148  280825642         Ramir     Woodlands  1.459510  103.765550
# 4153  290427273      Akmalina  Sungei Kadut  1.464260  103.744130
# 4154   31557595           Jay     Woodlands  1.458560  103.766840
# 4155  100026900  Dharmalingam     Woodlands  1.471150  103.769660
# 4156  266051529       Shareff     Woodlands  1.475250  103.781190
#
#             room_type  price  minimum_nights  availability_365  \
# 1050  Entire home/apt    233               2               325
# 1052  Entire home/apt    233               2               345
# 1061  Entire home/apt    230               6               277
# 1062  Entire home/apt    230               6               277
# 1067  Entire home/apt    230               6                 0
# ...               ...    ...             ...               ...
# 4148       Hotel room     19               1               144
# 4153     Private room     16               1                90
# 4154     Private room     16              30               332
# 4155     Private room     16               1                91
# 4156     Private room     15               1               342
#
#      neighbourhood_group last_review  total_review
# 1050      Central Region  2022-08-18             3
# 1052      Central Region  2022-09-07             8
# 1061      Central Region  2022-05-23             1
# 1062      Central Region  2022-09-17             2
# 1067      Central Region  2022-09-17             8
# ...                  ...         ...           ...
# 4148        North Region  2019-12-01             1
# 4153        North Region  2019-09-17             1
# 4154        North Region  2022-08-17             1
# 4155        North Region  2020-02-04             1
# 4156        North Region  2022-08-08            24
#
# [2050 rows x 14 columns]

# %% [markdown]
# ## Jarak Listing Teraktif Ke Pesisir

# %%
data_top_listing_10 = ps.sqldf(""" 
                                select id, name, host_name, sum(total_review) as total_review, room_type, price, latitude, longitude, neighbourhood, neighbourhood_group
                                from data
                                group by id
                                limit 10 
                                """)
data_top_listing = ps.sqldf(''' 
                              select id, name, host_name, sum(total_review) as total_review, room_type, price,latitude, longitude, neighbourhood, neighbourhood_group
                              from data
                              group by id
                              ''')

# %%
# define the coordinates of the Singapore coast

singapore_cost = (1.3008,103.9122 )
data_top_listing_10 = data_top_listing_10.sort_values('latitude')

dist_to_cost = []

for i in range(len(data_top_listing_10)):
  listing_data = (data_top_listing_10.loc[i, 'latitude'], data_top_listing_10.loc[i, 'longitude'])
  dist = haversine(singapore_cost, listing_data)
  dist_to_cost.append(dist)

data_top_listing_10['distance_to_coast'] = dist_to_cost
 



data_top_listing_10

# %%
plot_distance_cost = px.scatter(data_top_listing_10, x='name', y='total_review', size='distance_to_coast', color ='distance_to_coast', size_max=50, hover_data = ['price', 'room_type', 'neighbourhood', 'neighbourhood_group'])
plot_distance_cost.update_layout(title = '<b>Informasi Jarak Ke Pesisir Listing Teraktif<b>', title_font = dict(size = 20, color = 'black', family = 'arial'),title_x = 0.5)
plot_distance_cost.update_xaxes(title = 'Listing', title_font = dict(size = 18, color = 'black', family = 'arial'), tickfont=dict(size=12, color='black', family='arial'), tickangle = 20)
plot_distance_cost.update_yaxes(title = 'Jumlah kunjungan', title_font = dict(size = 18, color = 'black', family = 'arial'))

plot_distance_cost.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="283a8725-ffdd-4fca-9478-f0aeca909d3b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("283a8725-ffdd-4fca-9478-f0aeca909d3b")) {                    Plotly.newPlot(                        "283a8725-ffdd-4fca-9478-f0aeca909d3b",                        [{"customdata":[[55,"Private room","Bukit Merah","Central Region"],[49,"Private room","Bukit Merah","Central Region"],[49,"Private room","Bukit Merah","Central Region"],[79,"Private room","Newton","Central Region"],[79,"Private room","Newton","Central Region"],[184,"Private room","Tampines","East Region"],[85,"Private room","Tampines","East Region"],[145,"Private room","Tampines","East Region"],[85,"Private room","Tampines","East Region"],[42,"Private room","Tampines","East Region"]],"hovertemplate":"name=%{x}<br>total_review=%{y}<br>distance_to_coast=%{marker.color}<br>price=%{customdata[0]}<br>room_type=%{customdata[1]}<br>neighbourhood=%{customdata[2]}<br>neighbourhood_group=%{customdata[3]}<extra></extra>","legendgroup":"","marker":{"color":[7.174808102220614,7.399523424251357,7.343347312886614,11.286245292319071,7.213476847105023,8.196201554179895,11.424146038329395,11.224001250966259,7.631319772676856,8.350555271339864],"coloraxis":"coloraxis","size":[7.174808102220614,7.399523424251357,7.343347312886614,11.286245292319071,7.213476847105023,8.196201554179895,11.424146038329395,11.224001250966259,7.631319772676856,8.350555271339864],"sizemode":"area","sizeref":0.0045696584153317584,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["Cozy Blue Single Room","Cozy Blue Room with large window!","15 mins to Outram MRT Single Room","5 mins walk from Newton subway","5mins from Newton Train Station","Booking for 3 bedrooms","Room 2-near Airport & EXPO","Ensuite Room (Room 1 & 2) near EXPO","B&B  Room 1 near Airport & EXPO","Budget short stay room near  EXPO"],"xaxis":"x","y":[4,5,5,30,25,4,23,10,4,36],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinew ...

# %%
data_top_listing_10
# Out:
#        id                                 name  host_name  total_review  \
# 7  330089                Cozy Blue Single Room        Kay             4
# 6  324945    Cozy Blue Room with large window!        Kay             5
# 3  275344    15 mins to Outram MRT Single Room        Kay             5
# 5  294281       5 mins walk from Newton subway  Elizabeth            30
# 9  369141      5mins from Newton Train Station  Elizabeth            25
# 4  289234               Booking for 3 bedrooms    Belinda             4
# 2   71903           Room 2-near Airport & EXPO    Belinda            23
# 0   71609  Ensuite Room (Room 1 & 2) near EXPO    Belinda            10
# 1   71896      B&B  Room 1 near Airport & EXPO    Belinda             4
# 8  344803    Budget short stay room near  EXPO    Belinda            36
#
#    latitude  longitude  distance_to_coast
# 7   1.28652  103.81225           7.174808
# 6   1.28828  103.81020           7.399523
# 3   1.28836  103.81144           7.343347
# 5   1.31142  103.83924          11.286245
# 9   1.31144  103.83784           7.213477
# 4   1.34490  103.95979           8.196202
# 2   1.34531  103.96100          11.424146
# 0   1.34537  103.95887          11.224001
# 1   1.34754  103.95958           7.631320
# 8   1.34917  103.96090           8.350555

# %%
# !pip install streamlit
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting streamlit
#   Downloading streamlit-1.20.0-py2.py3-none-any.whl (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 66.3 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.9/dist-packages (from streamlit) (8.1.3)
# Requirement already satisfied: packaging>=14.1 in /usr/local/lib/python3.9/dist-packages (from streamlit) (23.0)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /usr/local/lib/python3.9/dist-packages (from streamlit) (4.5.0)
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 21.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from streamlit) (1.22.4)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 KB 21.1 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.9/dist-packages (from streamlit) (6.1.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from streamlit) (8.4.0)
# Requirement already satisfied: pandas<2,>=0.25 in /usr/local/lib/python3.9/dist-packages (from streamlit) (1.4.4)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.8.0-py2.py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 76.4 MB/s eta 0:00:00
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.9/dist-packages (from streamlit) (5.3.0)
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.9/dist-packages (from streamlit) (6.2)
# Collecting watchdog
#   Downloading watchdog-3.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 KB 10.1 MB/s eta 0:00:00
# Collecting blinker>=1.0.0
#   Downloading blinker-1.5-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: pyarrow>=4.0 in /usr/local/lib/python3.9/dist-packages (from streamlit) (9.0.0)
# Collecting semver
#   Downloading semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.9/dist-packages (from streamlit) (2.8.2)
# Collecting rich>=10.11.0
#   Downloading rich-13.3.2-py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.7/238.7 KB 24.2 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<4,>=3.12 in /usr/local/lib/python3.9/dist-packages (from streamlit) (3.19.6)
# Requirement already satisfied: altair<5,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from streamlit) (4.2.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.9/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tzlocal>=1.1 in /usr/local/lib/python3.9/dist-packages (from streamlit) (4.3)
# Requirement already satisfied: requests>=2.4 in /usr/local/lib/python3.9/dist-packages (from streamlit) (2.27.1)
# Collecting validators>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit) (4.3.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit) (3.1.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit) (0.12.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=1.4->streamlit) (3.15.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas<2,>=0.25->streamlit) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.4->streamlit) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.4->streamlit) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.4->streamlit) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.4->streamlit) (1.26.15)
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading Pygments-2.14.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 64.3 MB/s eta 0:00:00
# Collecting markdown-it-py<3.0.0,>=2.2.0
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.9/dist-packages (from tzlocal>=1.1->streamlit) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.9/dist-packages (from validators>=0.2->streamlit) (4.4.2)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->altair<5,>=3.2.0->streamlit) (2.1.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit) (22.2.0)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.9/dist-packages (from pytz-deprecation-shim->tzlocal>=1.1->streamlit) (2022.7)
# Building wheels for collected packages: validators
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19579 sha256=2e409e9db69fc7b4d805aba999ee4c71b1c72b70bd286d539b2f1cc9cf54d912
#   Stored in directory: /root/.cache/pip/wheels/2d/f0/a8/1094fca7a7e5d0d12ff56e0c64675d72aa5cc81a5fc200e849
# Successfully built validators
# Installing collected packages: watchdog, validators, smmap, semver, pympler, pygments, mdurl, blinker, pydeck, markdown-it-py, gitdb, rich, gitpython, streamlit
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.6.1
#     Uninstalling Pygments-2.6.1:
#       Successfully uninstalled Pygments-2.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# Successfully installed blinker-1.5 gitdb-4.0.10 gitpython-3.1.31 markdown-it-py-2.2.0 mdurl-0.1.2 pydeck-0.8.0 pygments-2.14.0 pympler-1.0.1 rich-13.3.2 semver-2.13.0 smmap-5.0.0 streamlit-1.20.0 validators-0.20.0 watchdog-3.0.0
